# %%
import allennlp
from allennlp.data.vocabulary import Vocabulary
from allennlp.data.dataset_readers import DatasetReader

from allennlp.data import Instance
from allennlp.data.token_indexers import TokenIndexer, SingleIdTokenIndexer
from allennlp.data.tokenizers import Token

from allennlp.data.tokenizers.word_splitter import SpacyWordSplitter
from allennlp.data.token_indexers import WordpieceIndexer, SingleIdTokenIndexer

_spacy_tok = SpacyWordSplitter(language='en_core_web_sm', pos_tags=False).split_words

# %%
from typing import *
from overrides import overrides

# %%
import numpy as np

# %%
# for papermill
testing = False # set to False when running experiments
debugging = False
seed = 1
use_bt = False
computational_batch_size = 128
batch_size = 128
lr = 4e-3
lr_schedule = "slanted_triangular"
epochs = 5 if not testing else 1
hidden_sz = 128
dataset = "jigsaw"
n_classes = 6
max_seq_len = 512
download_data = False
ft_model_path = "../data/jigsaw/ft_model.txt"
ft_compiled_path = "../data/jigsaw/ft_compiled.npy" # Embeddings generated from the vocabulary
data_vocab_path = "../data/jigsaw/data_vocab.bin"
max_vocab_size = 400000
dropouti = 0.2
dropoutw = 0.0
dropoute = 0.1
dropoute_max = None
dropoutr = 0.3 # TODO: Implement
val_ratio = 0.0
use_focal_loss = False
focal_loss_alpha = 1.
focal_loss_gamma = 2.
use_augmented = False
freeze_embeddings = True
mixup_ratio = 0.0
discrete_mixup_ratio = 0.0
attention_bias = True
use_attention_aux = False
weight_decay = 0.
bias_init = True
neg_splits = 1
num_layers = 2
rnn_type = "lstm"
rnn_residual = False
pooling_type = "augmented_multipool" # attention or multipool or augmented_multipool
model_type = "standard"
cache_elmo_embeddings = True
use_word_level_features = False
use_sentence_level_features = False
bucket = True
compute_thres_on_test = True
find_lr = False
permute_sentences = False
run_id = "error_analysis"
bert_oov_map_path = "../data/jigsaw/bert_oov_map.bin"

# %%
class Config(dict):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        for k, v in kwargs.items():
            setattr(self, k, v)
    
    def set(self, key, val):
        self[key] = val
        setattr(self, key, val)

# %%
# TODO: Can we make this play better with papermill?
config = Config(
    testing=testing,
    debugging=debugging,
    seed=seed,
    use_bt=use_bt,
    computational_batch_size=computational_batch_size,
    batch_size=batch_size,
    lr=lr,
    lr_schedule=lr_schedule,
    epochs=epochs,
    hidden_sz=hidden_sz,
    dataset=dataset,
    n_classes=n_classes,
    max_seq_len=max_seq_len, # necessary to limit memory usage
    ft_model_path=ft_model_path,
    max_vocab_size=max_vocab_size,
    dropouti=dropouti,
    dropoutw=dropoutw,
    dropoute=dropoute,
    dropoute_max=dropoute_max,
    dropoutr=dropoutr,
    val_ratio=val_ratio,
    use_focal_loss=use_focal_loss,
    focal_loss_alpha=focal_loss_alpha,
    focal_loss_gamma=focal_loss_gamma,
    use_augmented=use_augmented,
    freeze_embeddings=freeze_embeddings,
    attention_bias=attention_bias,
    use_attention_aux=use_attention_aux,
    weight_decay=weight_decay,
    bias_init=bias_init,
    neg_splits=neg_splits,
    num_layers=num_layers,
    rnn_type=rnn_type,
    rnn_residual=rnn_residual,
    pooling_type=pooling_type,
    model_type=model_type,
    cache_elmo_embeddings=cache_elmo_embeddings,
    use_word_level_features=use_word_level_features,
    use_sentence_level_features=use_sentence_level_features,
    mixup_ratio=mixup_ratio,
    discrete_mixup_ratio=discrete_mixup_ratio,
    bucket=bucket,
    compute_thres_on_test=compute_thres_on_test,
    permute_sentences=permute_sentences,
    find_lr=find_lr,
    run_id=run_id,
)

# %%
from pathlib import Path

DATA_ROOT = Path("../data") / config.dataset

# %%
reader_registry = {}
def register(name: str):
    def dec(x: Callable):
        reader_registry[name] = x
        return x
    return dec

# %%
import gc, csv

from allennlp.data.fields import TextField, SequenceLabelField, LabelField, MetadataField, ArrayField
import string
alphabet = set(string.ascii_lowercase)

sentence_level_features: List[Callable[[List[str]], float]] = [
#     lambda x: (np.log1p(len(x)) - 3.628) / 1.065, # stat computed on train set
]

word_level_features: List[Callable[[str], float]] = [
    lambda x: 1 if (x.lower() == x) else 0,
    lambda x: len([c for c in x.lower() if c not in alphabet]) / len(x),
]

def proc(x: str) -> str:
    if "uncased" in config.model_type:
        x = x.lower()
    if config.model_type == "standard":
        return x.lower()
    else:
        return x

class MemoryOptimizedTextField(TextField):
    @overrides
    def __init__(self, tokens: List[str], token_indexers: Dict[str, TokenIndexer]) -> None:
        self.tokens = tokens
        self._token_indexers = token_indexers
        self._indexed_tokens: Optional[Dict[str, TokenList]] = None
        self._indexer_name_to_indexed_token: Optional[Dict[str, List[str]]] = None
        # skip checks for tokens
    @overrides
    def index(self, vocab):
        super().index(vocab)
        self.tokens = None # empty tokens

@register("jigsaw")
class JigsawDatasetReader(DatasetReader):
    def __init__(self, tokenizer: Callable[[str], List[str]]=lambda x: x.split(),
                 token_indexers: Dict[str, TokenIndexer] = None, # TODO: Handle mapping from BERT
                 max_seq_len: Optional[int]=config.max_seq_len) -> None:
        super().__init__(lazy=False)
        self.tokenizer = tokenizer
        self.token_indexers = token_indexers or {"tokens": SingleIdTokenIndexer()}
        self.max_seq_len = max_seq_len

    @overrides
    def text_to_instance(self, tokens: List[str], id: str,
                         labels: np.ndarray) -> Instance:
        sentence_field = MemoryOptimizedTextField([proc(x) for x in tokens],
                                   self.token_indexers)
        fields = {"tokens": sentence_field}
        
        wl_feats = np.array([[func(w) for func in word_level_features] for w in tokens])
        fields["word_level_features"] = ArrayField(array=wl_feats)
        
        sl_feats = np.array([func(tokens) for func in sentence_level_features])
        fields["sentence_level_features"] = ArrayField(array=sl_feats)

        label_field = ArrayField(array=labels)
        fields["label"] = label_field

        return Instance(fields)
    
    @overrides
    def _read(self, file_path: str) -> Iterator[Instance]:
        with open(file_path) as f:
            reader = csv.reader(f)
            next(reader)
            for i, line in enumerate(reader):
                if len(line) == 9:
                    _, id_, text, *labels = line
                elif len(line) == 8:
                    id_, text, *labels = line
                else: raise ValueError(f"line has {len(line)} values")
                yield self.text_to_instance(
                    self.tokenizer(text),
                    id_, np.array([int(x) for x in labels]),
                )
                if config.testing and i == 1000: break

# %%
from tqdm import tqdm
import warnings

def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

def get_fasttext_embeddings(vocab: Vocabulary):
    prog_bar = tqdm(open(config.ft_model_path, encoding="utf8", errors='ignore'))
    prog_bar.set_description("Loading embeddings")
    embeddings_index = dict(get_coefs(*o.split(" ")) for o in prog_bar
                             if len(o)>100)
    all_embs = np.stack(embeddings_index.values())

    embeddings = np.zeros((config.vocab_size + 5, 300))
    n_missing_tokens = 0
    prog_bar = tqdm(vocab.get_index_to_token_vocabulary().items())
    prog_bar.set_description("Creating matrix")
    for idx, token in prog_bar:
        if idx == 0: continue # keep padding as all zeros
        if idx == 1: continue # Treat unknown words as dropped words
        if token == "[MASK]":
            embeddings[idx, :] = np.random.randn(300) * 0.5
        if token not in embeddings_index:
            n_missing_tokens += 1
            if n_missing_tokens < 10:
                warnings.warn(f"Token {token} not in embeddings: did you change preprocessing?")
            if n_missing_tokens == 10:
                warnings.warn(f"More than {n_missing_tokens} missing, supressing warnings")
        else:
            embeddings[idx, :] = embeddings_index[token]
    
    if n_missing_tokens > 0:
        warnings.warn(f"{n_missing_tokens} in total are missing from embedding text file")
    return embeddings

# %%
import random
from functools import wraps

def maybeshuffle(_tokenize):
    def func(*args, **kwargs):
        arr = _tokenize(*args, **kwargs)
        if config.permute_sentences:
            random.shuffle(arr)
        return arr
    return func

# %%
# Tokenizer and tokenizer index: THIS Is DIFFERENT FROM BERT!!!
token_indexer = SingleIdTokenIndexer(
    lowercase_tokens=True,
)
@maybeshuffle
def tokenizer(x: str):
    return [w.text for w in
            _spacy_tok(x)[:config.max_seq_len]]

# %%
reader = JigsawDatasetReader(
    tokenizer=tokenizer,
    token_indexers={"tokens": token_indexer}
)

# %%
train_ds, val_ds, test_ds = (reader.read(DATA_ROOT / fname) for fname in ["train_wo_val.csv",
                                                                          "val.csv",
                                                                          "test_proced.csv"])
# Out:
# 151592it [03:05, 815.43it/s]
# 7979it [00:07, 1026.20it/s]
# 63978it [01:18, 815.40it/s]

# %%
import pickle
with open("../data/jigsaw/train_ds.bin", "wb") as of:
    pickle.dump(train_ds, of)

# %%
import pickle
with open("../data/jigsaw/val_ds.bin", "wb") as of:
    pickle.dump(val_ds, of)

# %%
import pickle
with open("../data/jigsaw/test_ds.bin", "wb") as of:
    pickle.dump(test_ds, of)

# %%
full_ds = train_ds + val_ds + test_ds

# %%
from itertools import groupby
def remove_extra_chars(s, max_qty=2):
    res = [c * min(max_qty, len(list(group_iter))) for c, group_iter in groupby(s)] 
    return ''.join(res)

# %%
remove_extra_chars('abcdef')
# Out:
# 'abcdef'

# %%
from pytorch_pretrained_bert.tokenization import BertTokenizer

bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

# %%
vocab = Vocabulary.from_instances(full_ds, max_vocab_size=config.max_vocab_size)
# Out:
# 100%|██████████| 223549/223549 [00:18<00:00, 11866.52it/s]

# %%
prog_bar = tqdm(vocab.get_index_to_token_vocabulary().items())
token_arr = [token for idx, token in prog_bar]
# Out:
# 100%|██████████| 305140/305140 [00:00<00:00, 2142998.14it/s]

# %%
config.set("vocab_size", min(vocab.get_vocab_size(), config.max_vocab_size))
config.set("embedding_dim", 300)
fasttext_embeds = get_fasttext_embeddings(vocab)
# Out:
# Loading embeddings: : 317458it [00:30, 10274.49it/s]
# /home/anna/neuralnlp/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   # This is added back by InteractiveShellApp.init_path()
# Creating matrix: 100%|██████████| 305140/305140 [00:01<00:00, 236711.16it/s]

# %%
from scipy.spatial.distance import cosine, euclidean
from numpy.linalg import norm
w1 = fasttext_embeds[vocab.get_token_index('fcuk')]
w2 = fasttext_embeds[vocab.get_token_index('fuck')]
print(np.sum(w1 * w2)/norm(w1)/norm(w2), 1 - cosine(w1, w2))
# Out:
# 0.38523468070826167 0.3852346807082616

# %%
'fcuk' in bert_tokenizer.vocab
# Out:
# False

# %%
bert_vocab_toks = bert_tokenizer.vocab.keys()
vocab_toks = set( [w for idx, w in vocab.get_index_to_token_vocabulary().items() ])

# %%
len(vocab_toks), len(bert_vocab_toks)
# Out:
# (305140, 30522)

# %%
bert_vocab_ids = []

for tok in bert_vocab_toks:
    tok_id = vocab.get_token_index(tok)
    if tok_id > 1:
        bert_vocab_ids.append(tok_id)
        
bert_vocab_ids = np.array(bert_vocab_ids)

# %%
fasttext_embeds[bert_vocab_ids].shape
# Out:
# (22778, 300)

# %%
import nmslib, time

M = 25
efC = 200

num_threads = 0
index_time_params = {'M': M, 'indexThreadQty': num_threads, 'efConstruction': efC, 'post' : 0}
print('Index-time parameters', index_time_params)
# Out:
# Index-time parameters {'M': 25, 'indexThreadQty': 0, 'efConstruction': 200, 'post': 0}

# %%
# Space name should correspond to the space name 
# used for brute-force search
space_name='cosinesimil'


# Intitialize the library, specify the space, the type of the vector and add data points 
index = nmslib.init(method='hnsw', space=space_name, data_type=nmslib.DataType.DENSE_VECTOR) 
index.addDataPointBatch(fasttext_embeds[bert_vocab_ids])
# Out:
# 22778

# %%
# Create an index
start = time.time()
index_time_params = {'M': M, 'indexThreadQty': num_threads, 'efConstruction': efC}
index.createIndex(index_time_params) 
end = time.time() 
print('Index-time parameters', index_time_params)
print('Indexing time = %f' % (end-start))
# Out:
# Index-time parameters {'M': 25, 'indexThreadQty': 0, 'efConstruction': 200}
# Indexing time = 5.314431

# %%
# Setting query-time parameters
efS = 1000
K=10
query_time_params = {'efSearch': efS}
print('Setting query-time parameters', query_time_params)
index.setQueryTimeParams(query_time_params)
# Out:
# Setting query-time parameters {'efSearch': 1000}

# %%
tok_id = vocab.get_token_index('fuuck')
query_arr = [fasttext_embeds[tok_id]]
query_matrix = np.array(query_arr)
K=10
query_matrix.shape, tok_id
# Out:
# ((1, 300), 100538)

# %%
# Querying
query_qty = query_matrix.shape[0]
start = time.time() 
nbrs = index.knnQueryBatch(query_matrix, k = K, num_threads = num_threads)
end = time.time() 
print('kNN time total=%f (sec), per query=%f (sec), per query adjusted for thread number=%f (sec)' % 
      (end-start, float(end-start)/query_qty, num_threads*float(end-start)/query_qty))
# Out:
# kNN time total=0.005025 (sec), per query=0.005025 (sec), per query adjusted for thread number=0.000000 (sec)

# %%
nbrs[0][0], nbrs[0][1]
# Out:
# (array([11084, 21732, 19477, 15291, 22556, 17013, 18107, 20259, 20725,
#         16667], dtype=int32),
#  array([0.47294343, 0.48340237, 0.4915681 , 0.50250036, 0.50813234,
#         0.509331  , 0.5209646 , 0.53238195, 0.5377827 , 0.53826004],
#        dtype=float32))

# %%
for i in nbrs[0][0]:
    print(vocab.get_token_from_index(bert_vocab_ids[i]))
# Out:
# ninja
# minions
# yuki
# ryu
# gunslinger
# akira
# sakura
# mikey
# godzilla
# knocks

# %%
oov_toks = vocab_toks - bert_vocab_toks
query_arr = []
query_toks = []
for tok in oov_toks:
    tok_id = vocab.get_token_index(remove_extra_chars(tok))
    query_arr.append(fasttext_embeds[tok_id])
    query_toks.append(tok)
    
query_matrix = np.array(query_arr)
query_matrix.shape
# Out:
# (282362, 300)

# %%
# Setting query-time parameters
efS = 1000
K=10
query_time_params = {'efSearch': efS}
print('Setting query-time parameters', query_time_params)
index.setQueryTimeParams(query_time_params)
# Out:
# Setting query-time parameters {'efSearch': 1000}

# %%
# Querying
query_qty = query_matrix.shape[0]
start = time.time() 
nbrs = index.knnQueryBatch(query_matrix, k = K, num_threads = num_threads)
end = time.time() 
print('kNN time total=%f (sec), per query=%f (sec), per query adjusted for thread number=%f (sec)' % 
      (end-start, float(end-start)/query_qty, num_threads*float(end-start)/query_qty))
# Out:
# kNN time total=256.942548 (sec), per query=0.000910 (sec), per query adjusted for thread number=0.000000 (sec)

# %%
OOV_THRESHOLD=0.3 # We care only about very similar items
oov_map = dict()

for i in range(query_qty):
    nbr_ids = nbrs[i][0]
    nbr_dist = nbrs[i][1]
    query_tok = query_toks[i]
    
    for k in range(len(nbr_ids)):
        nbr_id = nbr_ids[k]
        tok_id = bert_vocab_ids[nbr_id]
        nbr_tok = vocab.get_token_from_index(tok_id)
        assert(query_tok != nbr_tok)
        if nbr_dist[k] <= OOV_THRESHOLD:
            oov_map[query_tok] = nbr_tok
            break

# %%
oov_map
# Out:
# {'refraction': 'wavelengths',
#  'requests#requests': 'requests',
#  'upadhyay': 'sharma',
#  'atherosclerotic': 'inflammation',
#  'fabricators': 'fabrication',
#  'macedonicity': 'macedonia',
#  'humanitarianism': 'humanitarian',
#  'veterinarians': 'veterinary',
#  'chellappa': 'menon',
#  'judgemental': 'judgement',
#  'elearning': 'learning',
#  'taman': 'jalan',
#  'humour~': 'humour',
#  'переломне': 'и',
#  'spacing': 'spaced',
#  'hellenization': 'hellenistic',
#  'lighthouses': 'lighthouse',
#  'neudeutschland': 'deutschland',
#  'uplands': 'upland',
#  'platform==': 'platforms',
#  'wikikikipedia': 'wikipedia',
#  'interpretation?==': 'interpretation',
#  'settlin': 'settling',
#  'heliskiing': 'skiing',
#  'psychopathy': 'schizophrenia',
#  'giganotosaurus': 'dinosaurs',
#  'romanians==': 'romanian',
#  'hypophyseal': 'congenital',
#  'senater': 'senate',
#  'http://usability.gov/pdfs/chapter11.pdf': 'pdf',
#  'знайти': 'в',
#  '4-electron': 'electron',
#  'свои': 'и',
#  'kammerphilharmonie': 'philharmonic',
#  'payable': 'payment',
#  'beaks': 'beak',
#  'disparagingly': 'sarcastically',
#  'metamorphism': 'sedimentary',
#  'ferenc': 'hungarian',
#  'someones': 'someone',
#  'inquisitions': 'inquisition',
#  'dreames': 'dreamer',
#  'mba(biotechnology': 'biotechnology',
#  'singapore==': 'singapore',
#  '1,039/smoothed': 'smoothed',
#  'heartened': 'disappointed',
#  'depressants': 'medication',
#  'frameshift': 'mutations',
#  'северными': 'и',
#  'труба': 'и',
#  'surah': 'qur',
#  'category:1985': 'category',
#  'salahuddin': 'syed',
#  'जैसे': 'এ',
#  'circulatng': 'circulating',
#  'replying': 'reply',
#  'الاحيان': 'و',
#  'swinton': 'warrington',
#  'accosts': 'confronts',
#  'teschen': 'silesia',
#  'discussion=': 'discussions',
#  'тела': 'и',
#  'na+/k+-atpase': 'proteins',
#  'incompatibilities': 'compatibility',
#  'wp.respectfully': 'politely',
#  'puntland': 'somalia',
#  'द्रारा': 'र',
#  'muffling': 'muffled',
#  'distasteful': 'disgusting',
#  'eepublicans': 'republicans',
#  'archive263#a': 'archive',
#  'intersex': 'transgender',
#  'herpes': 'infection',
#  'congratulations-': 'congratulations',
#  'displacement=': 'displacement',
#  'wirklichen': 'eine',
#  'manipulative': 'manipulating',
#  'overhanging': 'sloping',
#  'mexica': 'aztec',
#  'atheist?==': 'atheist',
#  'porgie': 'georgie',
#  'shōjo': 'manga',
#  'outermost': 'outer',
#  'croatiaosijek': 'croatia',
#  'hrvat': 'croatian',
#  'работа': 'и',
#  'shakespeare-': 'shakespeare',
#  'constantınople': 'constantinople',
#  '0011': '2011',
#  'bharatiyaji': 'bharatiya',
#  'peisistratus': 'athenian',
#  'sub)categorized': 'categorized',
#  'الارطى': 'و',
#  'offends': 'offended',
#  'bubonic': 'plague',
#  'replayed': 'replay',
#  'रामेश्वर': 'र',
#  'yekaterina': 'irina',
#  'nürburgring': 'porsche',
#  'apologising': 'apology',
#  'abrahamic': 'religions',
#  'holloway.jpg': 'holloway',
#  'pleasingly': 'pleasing',
#  'pelycosaur': 'dinosaur',
#  'hoist': 'hoisted',
#  'pimps': 'prostitutes',
#  'connecton': 'connector',
#  'stadium.jpg': 'stadium',
#  'synchronise': 'synchronized',
#  'https://en.wikipedia.org/wiki/user_talk:freerangefrog#a_big_fuck_you_to_you.2c_scum_of_the_earth.21.21.21_you_are_not_a_gentleman.21.21.21': '0',
#  'عن': 'و',
#  'hillsboroguh': 'hillsborough',
#  'laminated': 'welded',
#  '-absolutely-': 'absolutely',
#  'inprisoned': 'imprisoned',
#  'jaggayya': 'raju',
#  'города': 'и',
#  'circuses': 'circus',
#  'bumpers': 'bumper',
#  'beckert': 'becker',
#  'heals': 'heal',
#  'law|northern': 'northern',
#  'социалистической': 'и',
#  're)appointment': 'appointment',
#  'smugg': 'smuggling',
#  'monaghan': 'donegal',
#  'vlachs': 'serbs',
#  'neolithized': 'neolithic',
#  'depprotation': 'rotational',
#  'prostituting': 'prostitutes',
#  'zambian': 'zambia',
#  'стадий': 'и',
#  'yeshivah': 'yeshiva',
#  'الغيرة': 'ـ',
#  'biographies)#family': 'biographies',
#  'nonprofits': 'nonprofit',
#  'aristocrct': 'aristocratic',
#  'dumpling': 'pancakes',
#  'accommodates': 'accommodated',
#  'http://en.wikipedia.org/w/index.php?title=talk:mechwarrior_3&action;=edit': 'php',
#  'certaint': 'certainty',
#  'aqueous': 'soluble',
#  'river#pollution': 'pollution',
#  'programmatische': 'eine',
#  'triphenylmethyllithium': 'methyl',
#  'досад': 'и',
#  'brazilians': 'brazilian',
#  'сложная': 'и',
#  'paraglider': 'glider',
#  'wie': 'ich',
#  'ukraina': 'ukraine',
#  'http://en.wikipedia.org/w/index.php?title=management_of_savagery&diff;=624907296&oldid;=624906056': 'php',
#  'webforums': 'forums',
#  'candidacies': 'candidacy',
#  'consensus===': 'consensus',
#  'pragmatics': 'semantics',
#  'office-': 'office',
#  'wikipedia?=': 'wikipedia',
#  'huanqiu': 'qin',
#  'reblocking': 'blocking',
#  'bleeing': 'fleeing',
#  'leste': 'timor',
#  'yes|falkland': 'falkland',
#  'kompressor': 'compressor',
#  '19#neutrality': 'neutrality',
#  'вас': 'и',
#  'الداخلي': 'ـ',
#  'соцреализм.': 'и',
#  'varietals': 'wines',
#  'thirteenth.[vague': 'thirteenth',
#  'explanation.27.33.143.93': 'explanation',
#  'readiness==': 'readiness',
#  'транслитерация': 'и',
#  'immigrating': 'immigrated',
#  'nd': 'th',
#  'parkerson': 'parker',
#  'npa#removal': 'removal',
#  'natürlichen': 'eine',
#  'bourgeoisie': 'bourgeois',
#  'ilkhanids': 'caliphate',
#  'sockpup': 'sock',
#  'golfing': 'golf',
#  'pashë': 'albanian',
#  'visigothic': 'frankish',
#  'বিল': 'এ',
#  'moffats': 'moffat',
#  'deconfirming': 'confirming',
#  'enough.(i': 'enough',
#  'الدنيا': 'ـ',
#  'والشيطنة': 'ـ',
#  'सासाराम': 'न',
#  'wikipedia.tv': 'wikipedia',
#  'vquaker': 'quaker',
#  'shogunate': 'tokugawa',
#  'message.haha': 'message',
#  'repetive': 'repetition',
#  'blastocyst’': 'embryo',
#  'билиш': 'и',
#  'unattested': 'attested',
#  '1139': '113',
#  'banquets': 'banquet',
#  'annabel': 'annabelle',
#  'ātmaprajñānanda': 'sanskrit',
#  'αλέξανδρος': 'ο',
#  'irrespectively': 'regardless',
#  'আমায়': 'এ',
#  'aceh': 'sumatra',
#  'discussion.""[1': 'discussion',
#  'individual(s': 'individual',
#  'width:70': 'width',
#  'rajastani': 'rajasthan',
#  'hindusism': 'hinduism',
#  'chitra': 'mohan',
#  'swabia': 'bavaria',
#  'proclama': 'proclamation',
#  'recklessly': 'reckless',
#  'азербайджана': 'и',
#  'blocked!i': 'blocked',
#  'iranic': 'turkic',
#  'go!(piccolo': 'piccolo',
#  'ایرانی': 'و',
#  'dumont==': 'dumont',
#  'fpirits': 'spirits',
#  'romyosine': 'inhibition',
#  '-supreme': 'supreme',
#  'youtubes': 'youtube',
#  'assimilating': 'assimilation',
#  'sanjaks': 'ottoman',
#  'seasoning': 'roasted',
#  'globalising': 'globalization',
#  'rec.gambling.poker': 'poker',
#  'wahrscheinlichkeit': 'eine',
#  'singapore[2': 'singapore',
#  'explanation(s': 'explanation',
#  'bombing==': 'bombing',
#  'afrikaansafghanistan': 'afghanistan',
#  'socratic': 'socrates',
#  'coders': 'programmers',
#  'malappuram': 'kerala',
#  'http://abcnews.go.com/health/reproductivehealth/sex-study-female-orgasm-eludes-majority-women/story?id=8485289': '0',
#  'disturbs': 'disturb',
#  'maoism': 'marxism',
#  'linguists': 'linguistic',
#  'buffalows': 'buffalo',
#  'conserving': 'conserve',
#  'kajol': 'kapoor',
#  '|unjustified': 'justified',
#  'quote.-': 'quote',
#  'professes': 'confesses',
#  "paralysis'==": 'paralysis',
#  '1701#amendment': 'amendment',
#  'drinkies': 'drinking',
#  'collaborately': 'collaborating',
#  'apprehending': 'apprehension',
#  'هذا': 'ـ',
#  'woooooooooooooooooooooooooooooooo': 'woo',
#  'chracters': 'characters',
#  'retransmission': 'transmission',
#  'jerseyko': 'jersey',
#  'знакомых': 'и',
#  'nurmohammad': 'mohammad',
#  'episode?.the': 'episode',
#  'jealously': 'jealous',
#  'geographicaly': 'geographical',
#  'balangay': 'barangay',
#  'commendations==': 'commendation',
#  'evgeniy': 'sergey',
#  'التوفيق': 'ـ',
#  'reporting==': 'reporting',
#  'सूत्र': 'व',
#  'ridiculously': 'ridiculous',
#  'microinsurance': 'insurance',
#  '3-personnel': 'personnel',
#  'reopening': 'reopened',
#  'sajjan': 'singh',
#  'lászló': 'laszlo',
#  'immunol': 'antibodies',
#  'positivistic': 'empirical',
#  'obstructed': 'obstruction',
#  'message.i': 'message',
#  'http://en.wikipedia.org/w/index.php?title=children_in_need&diff;=171994422&oldid;=171993766': 'php',
#  'https://en.wikipedia.org/w/index.php?title=user_talk:mosfetfaser&diff;=602761816&oldid;=600751194': 'php',
#  'equipmenti': 'equipment',
#  'saorhgoshiudrhgoshlhasjrhguthslsierh': '159',
#  'polyisobutylene': 'polymers',
#  'isawesome': 'awesome',
#  'stringing': 'strings',
#  'tagging': 'tagged',
#  'articulating': 'articulated',
#  'शक्य': 'र',
#  'assurant': 'assurance',
#  "o'donovan": 'donovan',
#  'нарушающее': 'и',
#  'recomend': 'recommend',
#  'show_messages.php?board=909091235&topic;=23545754&page;=0\\': '0',
#  'demoliton': 'demolition',
#  'arbitration#onefortyone': 'arbitration',
#  'hypocritical': 'ignorant',
#  'syndicalism': 'socialism',
#  'scarring': 'swelling',
#  'illustrators': 'illustrator',
#  'suppresses': 'suppress',
#  'writs': 'writ',
#  'skunks': 'squirrels',
#  'basque?[i': 'basque',
#  'mujahideen': 'taliban',
#  'retold': 'tale',
#  'bhaskar': 'prakash',
#  'изображения': 'и',
#  'pratiquée': 'histoire',
#  'shoulde': 'shoulders',
#  '-—preceding': 'preceding',
#  'abolitionists': 'abolitionist',
#  'sources)say': 'sources',
#  'allergen': 'allergic',
#  'dislikes': 'dislike',
#  'archive==': 'archive',
#  'مرة': 'ـ',
#  'http://osaka.law.miami.edu/~froomkin/articles/cctlds-tm.pdf': '0',
#  'concurred': 'disagreed',
#  'profounded': 'profound',
#  'واريد': 'ـ',
#  'muhammadali': 'muhammad',
#  'bhaktivedanta': 'swami',
#  'grassroot': 'grassroots',
#  'unnecesssary': 'unnecessary',
#  'menschheit': 'und',
#  'eurovision#60th': 'eurovision',
#  'phonetical': 'phonetic',
#  'unhappiness': 'frustration',
#  'loggias': 'portico',
#  'mönchengladbach': 'dortmund',
#  'vasanthkumar': 'vijay',
#  'classifing': 'classifications',
#  'témoignages': 'histoire',
#  'civilizing': 'civilized',
#  'filles': 'les',
#  'المال.': 'و',
#  'railway-': 'railway',
#  'psychiatey': 'psychiatry',
#  'collaboratively': 'collaborative',
#  'luthern': 'lutheran',
#  'gauri': 'devi',
#  'rhythmically': 'rhythmic',
#  'source-': 'source',
#  'الساهر': 'ـ',
#  'unawareness': 'awareness',
#  'enemy1': 'enemy',
#  'xussein': 'hussein',
#  'analphabet': 'alphabet',
#  'kainuunmaa': 'finnish',
#  'promotionally': 'promotional',
#  'seceding': 'secession',
#  'gamest': 'gamer',
#  'permisson': 'permission',
#  'teenaged': 'teenage',
#  'technologies-': 'technologies',
#  'новости': 'и',
#  'prostitutes."";really': 'prostitutes',
#  'insecurely': 'securely',
#  'blockee': 'blocking',
#  'admininistrators': 'administrators',
#  '534': '34',
#  'rheumatic': 'arthritis',
#  'premiering': 'premiered',
#  'neoliberalism': 'liberalism',
#  'abused’': 'abused',
#  'http://en.wikipedia.org/w/index.php?title=talk%3aphyllis_schlafly&action;=historysubmit&diff;=558569883&oldid;=558146339': 'php',
#  'speedy|speedy': 'speedy',
#  'benthic': 'invertebrates',
#  'направил': 'и',
#  'bioavailability': 'toxicity',
#  'loyalism': 'loyalist',
#  'cleans': 'cleaning',
#  'coarse.u': 'coarse',
#  'archduchy': 'habsburg',
#  'counter)d': 'counter',
#  'macedonia(region': 'macedonia',
#  'pratapgarh': 'uttar',
#  'supplementing': 'supplemented',
#  'yoshizo': 'tanaka',
#  'moulvibazar': 'dhaka',
#  'unnerved': 'terrified',
#  'http://en.wikipedia.org/w/index.php?title=che_guevara&diff;=39908363&oldid;=39772586': 'php',
#  'disowns': 'confesses',
#  'cowered': 'frightened',
#  'heterosexuell': 'heterosexual',
#  'structurer': 'structure',
#  'laceration': 'swelling',
#  'messsages': 'messages',
#  'asghar': 'mohammad',
#  'koreasaurus': 'dinosaurs',
#  'ɽ': 'ʋ',
#  'implantable': 'implant',
#  'homophobic-': 'racist',
#  'wichtige': 'eine',
#  'rhinoplasty': 'surgery',
#  'kỳ': 'minh',
#  'revisiting': 'revisited',
#  'forteenth': 'fifteenth',
#  'puppeteered': 'puppets',
#  'subcatgories': 'categories',
#  'candidatethis': 'candidates',
#  'williamsburgland': 'williamsburg',
#  'newpapers': 'newspapers',
#  'প্রবাসীদের': 'এ',
#  'multiculturalists': 'multicultural',
#  'lehigh&hudson': 'lehigh',
#  'срето': 'и',
#  'forensics': 'forensic',
#  'firmament': 'heavens',
#  'arkensaurus': 'dinosaurs',
#  'imperfectly': 'imperfect',
#  'redshirted': 'freshman',
#  'gigabit': 'ethernet',
#  'trans]jordanian': 'jordanian',
#  'lusaka': 'zambia',
#  'wikipedia.com': 'wikipedia',
#  'consumer""on': 'consumer',
#  'zinta': 'kapoor',
#  'misfunctioning': 'dysfunction',
#  'maximum)[5': 'maximum',
#  'geneticists': 'genetics',
#  'prussias': 'prussia',
#  'offensively': 'offensive',
#  'gng': 'fails',
#  'hellenious': 'hellenistic',
#  'error==': 'error',
#  'uninformed': 'ignorant',
#  'consensues': 'consensus',
#  'pardoned': 'imprisoned',
#  'altaf': 'hussain',
#  'germany|de': 'germany',
#  'sponsons': 'superstructure',
#  'invalidity': 'validity',
#  'nonverbal': 'cognition',
#  'conditionals': 'conditional',
#  'abvious': 'obvious',
#  'referenda': 'referendum',
#  'phnom': 'cambodia',
#  'stress==': 'stress',
#  'agknowledge': 'knowledge',
#  'unacceptbale': 'unacceptable',
#  'согласно': 'и',
#  'dangled': 'dangling',
#  'إن': 'ـ',
#  'dreamt': 'dreamed',
#  'thankyou': 'thank',
#  'purchased=': 'purchased',
#  'terrifies': 'terrified',
#  'unsurprising': 'surprising',
#  'subtley': 'subtle',
#  'mianagawa': 'chiba',
#  '': 'tt',
#  'tritheist': 'atheist',
#  'результатам': 'и',
#  'pseudomonas': 'bacterium',
#  'player""of': 'player',
#  'swedisch': 'swedish',
#  'puertorrican': 'puerto',
#  'melanin': 'pigment',
#  'subways': 'subway',
#  'stylizes': 'stylized',
#  'crimsone': 'crimson',
#  'anyway.~': 'anyway',
#  'sporangiophore': 'spores',
#  'painfulness': 'painful',
#  'skeptism': 'skepticism',
#  'glycine': 'amino',
#  'emailuser': 'email',
#  'hotel3600': 'hotel',
#  'vladimirnovna': 'vladimir',
#  'pragmatism': 'marxism',
#  'héctor': 'enrique',
#  'flusher': 'flush',
#  'voltages': 'voltage',
#  'hurricanenotashoe': 'hurricane',
#  'papuan': 'papua',
#  'http://it.wikipedia.org/wiki/wikipedia:amministratori/riconferma_annuale/archivio/archivio_riconferme_tacite/2012#vituzzu': '0',
#  'ausgezeichnet': 'und',
#  'rockefellers': 'rockefeller',
#  'fingerson': 'fingers',
#  'shinkenger': 'sentai',
#  'tools-': 'tools',
#  'چشمان': 'د',
#  'vietnamien': 'viet',
#  'indentured': 'slaves',
#  'characterisations': 'characterization',
#  'apologises': 'realises',
#  'shaktism': 'hinduism',
#  'hyperparathyroidism': 'thyroid',
#  'organization.(might': 'organization',
#  'hydrophilanthropy': 'philanthropy',
#  'devoting': 'devote',
#  '-jonathan': 'jonathan',
#  'https://en.wikipedia.org/w/index.php?title=filter&diff;=prev&oldid;=483244966': 'php',
#  'ipads': 'ipad',
#  'fijians': 'fiji',
#  'curries': 'dishes',
#  'reliability?219.35.22.28': 'reliability',
#  'villain|villainous': 'villain',
#  'congratualtions': 'congratulations',
#  'muffed': 'fumbled',
#  'ленину': 'и',
#  'garciaw': 'garcia',
#  'contradictorily': 'contradictory',
#  'достоевский': 'и',
#  'kallakurichi': 'taluk',
#  'पास': 'এ',
#  'министру': 'и',
#  'bellamy==': 'bellamy',
#  'waveform': 'amplitude',
#  'σ-finite': 'finite',
#  'influentials': 'influential',
#  'thiazolidinedione': 'methyl',
#  'bitchy': 'bitch',
#  'pseudotensors': 'tensor',
#  'linuxdistros': 'linux',
#  'vilnietis': 'vilnius',
#  'threatened,’': 'threatened',
#  'mutatation': 'mutation',
#  'истребители': 'и',
#  'archbishops': 'bishops',
#  'a102': '102',
#  'levothyroxine': 'medications',
#  'http://en.wikipedia.org/w/index.php?title=wikipedia%3arequests_for_checkuser%2fcase%2fya_ya_ya_ya_ya_ya&diff;=74728367&oldid;=74710126': 'php',
#  'aaliyah': 'rihanna',
#  '-protein\\chemist': 'proteins',
#  '3-clicks': 'clicks',
#  '^^extremely': 'extremely',
#  'insightful': 'thoughtful',
#  'hvac': 'plumbing',
#  'нация': 'и',
#  'http://members.tripod.com/george_parada/prod.htm#price': 'www',
#  'latakia': 'aleppo',
#  'critics,[1': 'critics',
#  'genres==': 'genres',
#  'decides-': 'decides',
#  "wikipedia'ism": 'wikipedia',
#  'intelligible': 'spoken',
#  'rockets71': 'rocket',
#  'mendelssohns': 'brahms',
#  'astronomica': 'astronomical',
#  'morteza': 'reza',
#  'madonna.com': 'madonna',
#  'electromagnetical': 'electromagnetic',
#  'vedics': 'vedic',
#  'fabricator': 'fabrication',
#  'unincorperated': 'unincorporated',
#  'eurasia': 'eurasian',
#  'יהודיים': 'hebrew',
#  'deploys': 'deploy',
#  'priority=': 'priority',
#  'restrictively': 'restrictive',
#  'airbases': 'airfields',
#  'undermining': 'undermine',
#  'deconstructivism': 'modernism',
#  'suzerainty': 'vassal',
#  'unintuitive': 'intuitive',
#  'saraiki': 'urdu',
#  'обнимая': 'и',
#  'crests': 'crest',
#  'ditary': 'hereditary',
#  'almería': 'zaragoza',
#  '1960)episode': 'episode',
#  'luo': 'jiang',
#  'превосходительству': 'и',
#  'untimely': 'death',
#  'honouring': 'honour',
#  'pyrenees33': 'pyrenees',
#  '116th': '16th',
#  'morcha': 'bharatiya',
#  'mannner': 'manner',
#  'postanarchism': 'marxism',
#  'nagotiate': 'negotiate',
#  'http://en.wikipedia.org/w/index.php?title=recording_industry_association_of_america&diff;=117602726&oldid;=117562188': 'php',
#  'http://en.wikipedia.org/w/index.php?title=user_talk:thewolfstar&redirect;=no': 'php',
#  'находится': 'и',
#  'reactivate': 'activate',
#  'teacher(s': 'teacher',
#  'booooooom': 'boom',
#  'amitriptyline': 'medications',
#  'neurotransmitter': 'receptors',
#  'setswana': 'afrikaans',
#  'handset': 'smartphone',
#  'فيها': 'ـ',
#  'magiranger': 'sentai',
#  'thiol': 'ligand',
#  'discussion.71.48.135.174': 'discussions',
#  'stylings': 'styling',
#  'кого': 'и',
#  'overcompensating': 'compensate',
#  'tremors': 'tremor',
#  'hesitating': 'hesitation',
#  'arthritides': 'arthritis',
#  'убедить': 'в',
#  'kunstrukitv': 'kunst',
#  'scrotum': 'penis',
#  'alphabeth': 'alphabet',
#  'functionalist': 'modernist',
#  'гол.': 'и',
#  'revision==': 'revision',
#  'deepak': 'kumar',
#  'cadens': 'caden',
#  'elven': 'elves',
#  'http://24.media.tumblr.com/tumblr_ljx3gfswyh1qzhm51o1_500.png': '0',
#  'souichiro': 'yuki',
#  'michigan==': 'michigan',
#  'talk|contributions': 'contributions',
#  'fatih': 'istanbul',
#  'homosexualtity': 'homosexual',
#  'criticising': 'criticised',
#  'meted': 'punishments',
#  'school#mascot': 'school',
#  'islam(i.e': 'islam',
#  'peloponnese': 'aegean',
#  'indef': 'blocked',
#  '24/9/2010': '2010',
#  'candidates/2012': 'candidates',
#  'vamana': 'vishnu',
#  'gautam': 'sharma',
#  'czechs': 'hungarians',
#  'postmodernism': 'modernism',
#  'prairies': 'prairie',
#  'electrosensitivity': 'sensitivity',
#  'zentralasiatischen': 'und',
#  'meshulam': 'moshe',
#  'etiology': 'diagnosis',
#  '-official': 'official',
#  'κατι': 'ο',
#  'bypasses': 'bypass',
#  'bethelehem': 'bethlehem',
#  'clearand': 'clearance',
#  'immaturaty': 'immature',
#  'capitulate': 'surrender',
#  'दी': 'व',
#  'сраный': 'и',
#  'bhave': 'narayan',
#  'novosibirsk': 'moscow',
#  'conflictive': 'conflicting',
#  'conjugations': 'verbs',
#  'outlandish': 'outrageous',
#  'subatomic': 'particle',
#  'category:1957': 'category',
#  'eurasia.net': 'eurasian',
#  'infrastructural': 'infrastructure',
#  'rookiee': 'rookie',
#  'hungarizied': 'hungarian',
#  'phightins': 'utc',
#  'accessibility#image': 'accessibility',
#  'satendra': 'sharma',
#  'прямой': 'и',
#  'category:2013': 'category',
#  'policies[edit': 'policies',
#  'tazz""(producer': 'producer',
#  'amaravathi': 'nadu',
#  'subjectivist': 'marxism',
#  'heretic': 'heresy',
#  'الاسلام': 'و',
#  'lithics': 'neolithic',
#  'motherfucker=': 'fuck',
#  'المزاحمة': 'ـ',
#  'obesities': 'obesity',
#  'proceduraly': 'procedural',
#  'paragraphing': 'paragraph',
#  'f11': 'f1',
#  'fingerprint': 'fingerprints',
#  'articles-': 'articles',
#  'enought': 'enough',
#  'گرفته': 'ـ',
#  'panchayatana': 'panchayat',
#  'français': 'francais',
#  'fortnightly': 'monthly',
#  'closeted': 'homosexual',
#  'denglish': 'english',
#  'поправили': 'и',
#  'anatolianism': 'anatolia',
#  'albums)': 'albums',
#  'bethoven': 'beethoven',
#  'والاخطر': 'ـ',
#  'asunción': 'montevideo',
#  'endocrinol': 'cardiovascular',
#  'bloggish': 'blogs',
#  'injection,169.139.19.174': 'injection',
#  'desperatly': 'desperately',
#  'google.ba': 'google',
#  'creek==': 'creek',
#  'québec': 'quebec',
#  'марсии': 'и',
#  'sheffield.jpg': 'sheffield',
#  'inadvertly': 'inadvertently',
#  'commisioner': 'commissioner',
#  'socioeconomic': 'socio',
#  'существу': 'и',
#  'vedantic': 'vedic',
#  'остальные': 'и',
#  'supernaturalism': 'supernatural',
#  'warms': 'warmed',
#  'mischievious': 'mischievous',
#  'السمعية': 'ـ',
#  'drupes': 'fruits',
#  'checking===': 'checking',
#  'toylines': 'transformers',
#  'brian:_portrait_of_a_dog': '0',
#  'caters': 'cater',
#  'encyclopaediais': 'encyclopedia',
#  'clayface': 'batman',
#  'http://en.wikipedia.org/w/index.php?title=wikipedia:administrators%27_noticeboard/incidents&diff;=prev&oldid;=534670252': 'php',
#  'vikipedia': 'wikipedia',
#  'aforementionned': 'aforementioned',
#  'reformulation': 'formulation',
#  'encyclopaedia': 'encyclopedia',
#  'audits': 'audit',
#  'thiols': 'oxidation',
#  'multiplayers': 'multiplayer',
#  'kunwar': 'singh',
#  'modernists': 'modernist',
#  'ppppppppppppppppppppppppp': 'pp',
#  'cristopher': 'christopher',
#  'flirtation': 'flirting',
#  'renderings': 'rendering',
#  'http://en.wikipedia.org/w/index.php?title=lgbt_parenting&diff;=497585303&oldid;=497583187': 'php',
#  'desyracuse': 'syracuse',
#  'kapoori': 'kapoor',
#  'atolls': 'atoll',
#  'spellchecking': 'checking',
#  'sameer': 'kumar',
#  'tabasco': 'oaxaca',
#  'liinguistic': 'linguistic',
#  'http://en.wikipedia.org/w/index.php?title=david_icke&diff;=prev&oldid;=175145716': 'php',
#  'astronautics': 'aeronautics',
#  'statured': 'stature',
#  'دارد.سنيان': 'د',
#  'ergebnisslos': 'geschichte',
#  'retailing': 'retail',
#  'shiho': 'yuki',
#  'reviewing’': 'reviewing',
#  '|experiencing': 'experiencing',
#  'unreliabe': 'unreliable',
#  'возможность': 'и',
#  'fucker': 'fuck',
#  'mahamuni': 'buddha',
#  'transferase': 'enzyme',
#  'reportin': 'reporting',
#  'coulters': 'coulter',
#  'anomalepidae': 'genus',
#  'sgi(international': 'international',
#  'treatises': 'treatise',
#  'expansions': 'expansion',
#  'agreeeing': 'agreeing',
#  'faired': 'fuselage',
#  'jaarboek': 'het',
#  'offff': 'off',
#  'ordaining': 'ordained',
#  'hyperinflations': 'inflation',
#  'http://netopia.ph/home/tabid/36/entryid/25/ip-e-games-signs-agreement-with-epldt-for-digital-paradise.aspx': '0',
#  'consciounce': 'conscious',
#  'eskisehir': 'ankara',
#  'causality': 'causal',
#  'diff': 'undo',
#  'http://en.wikipedia.org/w/index.php?title=category:you_do_not_own_the_ys_article.&action;=edit&redlink;=1': 'php',
#  'करती': 'न',
#  'hemorrhages': 'inflammation',
#  'замечания': 'и',
#  'краще': 'и',
#  'electives': 'courses',
#  'sexualised': 'sexuality',
#  'assassinations': 'assassination',
#  'almight': 'almighty',
#  'transnistria': 'moldova',
#  'sockpuppetconfirmed|ron': 'sock',
#  'iraqiya': 'iraqi',
#  'tab122': '122',
#  'jewish(rumor': 'jewish',
#  'героически': 'и',
#  'gallbladder': 'bladder',
#  'headquaters': 'headquarters',
#  'hotel==': 'hotels',
#  'rigs': 'rig',
#  'irrationality': 'irrational',
#  'escalation': 'escalated',
#  'carnivores': 'mammals',
#  'ounces': 'ounce',
#  'shockingly': 'shocking',
#  'reliabl': 'reliable',
#  'launder': 'laundering',
#  'siliceous': 'sedimentary',
#  'eicosapentanoic': 'acid',
#  'inexperianced': 'inexperienced',
#  'foreman\u200e': 'foreman',
#  'mythologies': 'mythology',
#  'הדברים': 'ת',
#  'featherstone': 'warrington',
#  'sitaram': 'narayan',
#  'slang-': 'slang',
#  'bg(fucking': 'fucking',
#  'atheists': 'atheist',
#  'anywayz': 'anyway',
#  'newspapers.com': 'newspapers',
#  'unconstructive': 'constructive',
#  'seats.arena': 'seats',
#  'indecency': 'obscene',
#  'nothernmost': 'southernmost',
#  'sympathies': 'sympathy',
#  'misconfigured': 'configured',
#  'emit': 'emitted',
#  'darbar': 'sahib',
#  'compressing': 'compression',
#  'http://en.wikipedia.org/w/index.php?title=kumdo&diff;=250246779&oldid;=250235822': 'php',
#  'nuetrality': 'neutrality',
#  'embarrassinbly': 'embarrassing',
#  'constraint==': 'constraint',
#  'frauds': 'fraud',
#  'flattening': 'flattened',
#  'happened?==': 'happened',
#  'обосновано': 'и',
#  'criticismsthat': 'criticisms',
#  'germanised': 'germanic',
#  'प्रकार': 'व',
#  'spontanously': 'spontaneously',
#  'epinephrine': 'insulin',
#  'myong': 'yong',
#  'swanseas': 'swansea',
#  'biotech': 'biotechnology',
#  'عين': 'ـ',
#  'fatiguing': 'fatigue',
#  'spinster': 'housekeeper',
#  'orthopaedics': 'surgical',
#  'california|kakonkaruk': 'california',
#  'ukrainian==': 'ukrainian',
#  'workshop\u200e': 'workshop',
#  'missunderstand': 'understand',
#  'speyer': 'mainz',
#  'minted': 'coins',
#  'specialistic': 'specialised',
#  'yoourself': 'yourself',
#  'offensive.http://en.wikipedia.org/w/index.php?title=user_talk%3ao_fenian&action;=historysubmit&diff;=384975490&oldid;=384966890': 'php',
#  'représentaion': 'dans',
#  'implementational': 'implementation',
#  'statism': 'liberalism',
#  'ह्या': 'व',
#  'ethnographic': 'anthropological',
#  'byelorussian': 'belarusian',
#  'siècle': 'histoire',
#  'residencies': 'residency',
#  'paragrap': 'paragraph',
#  'bioelectrochemical': 'inorganic',
#  'diese': 'eine',
#  'reestablishment': 'establishment',
#  'behaviour?': 'behaviour',
#  'j.n.bhattacharya': 'mukherjee',
#  'bladders': 'bladder',
#  'tiffany==': 'tiffany',
#  'humorously': 'humorous',
#  'quasiturbine': 'turbine',
#  'hanumantha': 'lakshmi',
#  'myspacer': 'myspace',
#  'infractions': 'offenses',
#  'languageru==': 'language',
#  'brezhnev': 'stalin',
#  'guha': 'mukherjee',
#  'occupatiional': 'occupations',
#  'foles': 'interceptions',
#  "someone'd": 'someone',
#  'lard': 'butter',
#  'версий': 'с',
#  'forevermore': 'forever',
#  'australia|australian': 'australian',
#  'classificationand': 'classifications',
#  'misbelief': 'disbelief',
#  '03/technology': 'technology',
#  'office.[8': 'offices',
#  'blocks==': 'blocks',
#  'noblemen': 'nobles',
#  "d'administration": 'administration',
#  'solubles': 'soluble',
#  'cronicle': 'chronicle',
#  'standard.06': 'standard',
#  'exclusivelly': 'exclusively',
#  'displeased': 'angered',
#  'nach': 'und',
#  'рисунком': 'и',
#  'geomagnetic': 'magnetic',
#  'balkh': 'kabul',
#  'priviledges.-': 'privileges',
#  'ani#disruption': 'disruption',
#  'deranged': 'crazed',
#  'đurović': 'montenegrin',
#  'categorizing': 'categories',
#  'unmistakenly': 'mistakenly',
#  'hideo': 'kenji',
#  'calibration': 'measurements',
#  'milwaukeeans': 'milwaukee',
#  'trivialties': 'trivial',
#  'sheikhupura': 'lahore',
#  'http://justiceforjeremiah.com/larouche_network_canada.html': '0',
#  'misunderstanings': 'misunderstanding',
#  'not#wikipedia': 'wikipedia',
#  'understandng': 'understand',
#  'japanimation': 'animation',
#  'classifies': 'classified',
#  'curve-': 'curve',
#  'kaushish': 'sharma',
#  'instablocked': 'blocked',
#  'uncertaintly': 'uncertainty',
#  'encouraged.|': 'encouraged',
#  'untrimmed': 'trimmed',
#  'poland.[4': 'poland',
#  'contrabass': 'clarinet',
#  'http://en.wikipedia.org/w/index.php?title=user_talk:sceptre&oldid;=378831852': 'php',
#  'cirumstances': 'circumstances',
#  'paleontology': 'geology',
#  'photograh': 'photographs',
#  'الهدنة': 'ـ',
#  'fulfilment': 'fulfillment',
#  'revisiondeleted': 'revisions',
#  'bian': 'liang',
#  'мешать': 'в',
#  'distilling': 'distillery',
#  'distinguishment': 'distinguishing',
#  'conclusin': 'conclusions',
#  'три': 'и',
#  'puppets|4=3669272': 'puppets',
#  'interstates': 'interstate',
#  'warning""due': 'warning',
#  'counterfeiting': 'laundering',
#  'https://en.wikipedia.org/w/index.php?title=user_talk:benlinus1214&action;=edit&section;=new': 'php',
#  'http://militera.lib.ru/memo/german/bidermann_gh/07.html': '0',
#  'vulgarism': 'vulgar',
#  'hypertention': 'diabetes',
#  'ей': 'в',
#  'hindering': 'preventing',
#  'persons#people_who_are_relatively_unknown': '1837',
#  'superstore': 'supermarket',
#  'breakdowns': 'breakdown',
#  'володієте': 'в',
#  'decision#my': 'decision',
#  'arbitration_enforcement#gatoclass': 'arbitration',
#  'year""colorectal': 'cancers',
#  'districts.in': 'districts',
#  'germany::de': 'germany',
#  'disadvantaged""u.s.': 'disadvantaged',
#  'tourisms': 'tourism',
#  'phillipino': 'filipino',
#  'chassidic': 'rabbi',
#  'المتامرين': 'ـ',
#  'stringybark': 'eucalyptus',
#  'widerlegung': 'geschichte',
#  'dhoom': 'bollywood',
#  'spotlighting': 'spotlight',
#  '1923|publisher': 'publisher',
#  'helens=': 'helens',
#  "sto['scomments": 'comments',
#  'الحياة.': 'ـ',
#  'прагматик': 'в',
#  'gelderland': 'groningen',
#  'الافاه': 'و',
#  '1353': '135',
#  '|atheist': 'atheist',
#  'barraza': 'castillo',
#  'delltg5/nintendo': 'nintendo',
#  'ineffective1': 'ineffective',
#  'ваши': 'и',
#  'sibilant': 'consonants',
#  'efrat': 'moshe',
#  'martialed': 'acquitted',
#  'repressing': 'repression',
#  'tridentine': 'liturgy',
#  'paganism': 'pagan',
#  'талибан': 'и',
#  'марун': 'и',
#  'faaa': 'faa',
#  'undertakes': 'undertake',
#  'zeitung': 'neue',
#  'fianna': 'gael',
#  'yasser': 'mahmoud',
#  'syndicate[11': 'syndication',
#  'northeaster': 'northeastern',
#  'restructure': 'restructuring',
#  'alprazolam': 'medications',
#  'draft-': 'draft',
#  'policies"")': 'policies',
#  'pronunced': 'pronunciation',
#  'huntingdonshire': 'cambridgeshire',
#  'calculus?==': 'calculus',
#  'shotguns': 'firearms',
#  'ossowski': 'stanisław',
#  'athletico': 'athletic',
#  'shaykh': 'imam',
#  'individuals,[2][8]researchers': 'individuals',
#  'rustaveli': 'tbilisi',
#  'tumor.[4': 'tumor',
#  'traveller101': 'traveller',
#  'necessitate': 'necessitated',
#  'manoportraits': 'portraits',
#  'brussels.[5': 'brussels',
#  '-energy': 'energy',
#  '9.atlantic': 'atlantic',
#  'redskin': 'redskins',
#  'sneer': 'sneered',
#  ...}

# %%
import pickle

with open(bert_oov_map_path, 'wb') as of:
    pickle.dump(oov_map, of)

# %%
bert_oov_map_path
# Out:
# '../data/jigsaw/bert_oov_map.bin'

# %%
with open(bert_oov_map_path, 'rb') as f:
    tmp = pickle.load(f)

# %%
import pickle

with open(data_vocab_path, 'wb') as of:
    pickle.dump(vocab, of)


# Save data to use in other notebooks
np.save(ft_compiled_path, fasttext_embeds)
