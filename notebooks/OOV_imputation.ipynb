# %%
import allennlp
from allennlp.data.vocabulary import Vocabulary
from allennlp.data.dataset_readers import DatasetReader

from allennlp.data import Instance
from allennlp.data.token_indexers import TokenIndexer, SingleIdTokenIndexer
from allennlp.data.tokenizers import Token

from allennlp.data.tokenizers.word_splitter import SpacyWordSplitter
from allennlp.data.token_indexers import WordpieceIndexer, SingleIdTokenIndexer

_spacy_tok = SpacyWordSplitter(language='en_core_web_sm', pos_tags=False).split_words
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
from typing import *
from overrides import overrides

# %%
import numpy as np

# %%
# for papermill
testing = False # set to False when running experiments
debugging = False
seed = 1
use_bt = False
computational_batch_size = 128
batch_size = 128
lr = 4e-3
lr_schedule = "slanted_triangular"
epochs = 5 if not testing else 1
hidden_sz = 128
dataset = "jigsaw"
n_classes = 6
max_seq_len = 512
download_data = False
ft_model_path = "../data/jigsaw/ft_model.txt"
max_vocab_size = 400000
dropouti = 0.2
dropoutw = 0.0
dropoute = 0.1
dropoute_max = None
dropoutr = 0.3 # TODO: Implement
val_ratio = 0.0
use_focal_loss = False
focal_loss_alpha = 1.
focal_loss_gamma = 2.
use_augmented = False
freeze_embeddings = True
mixup_ratio = 0.0
discrete_mixup_ratio = 0.0
attention_bias = True
use_attention_aux = False
weight_decay = 0.
bias_init = True
neg_splits = 1
num_layers = 2
rnn_type = "lstm"
rnn_residual = False
pooling_type = "augmented_multipool" # attention or multipool or augmented_multipool
model_type = "standard"
cache_elmo_embeddings = True
use_word_level_features = False
use_sentence_level_features = False
bucket = True
compute_thres_on_test = True
find_lr = False
permute_sentences = False
run_id = "error_analysis"
bert_oov_map_path = "../data/jigsaw/bert_oov_map.bin"

# %%
class Config(dict):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        for k, v in kwargs.items():
            setattr(self, k, v)
    
    def set(self, key, val):
        self[key] = val
        setattr(self, key, val)

# %%
# TODO: Can we make this play better with papermill?
config = Config(
    testing=testing,
    debugging=debugging,
    seed=seed,
    use_bt=use_bt,
    computational_batch_size=computational_batch_size,
    batch_size=batch_size,
    lr=lr,
    lr_schedule=lr_schedule,
    epochs=epochs,
    hidden_sz=hidden_sz,
    dataset=dataset,
    n_classes=n_classes,
    max_seq_len=max_seq_len, # necessary to limit memory usage
    ft_model_path=ft_model_path,
    max_vocab_size=max_vocab_size,
    dropouti=dropouti,
    dropoutw=dropoutw,
    dropoute=dropoute,
    dropoute_max=dropoute_max,
    dropoutr=dropoutr,
    val_ratio=val_ratio,
    use_focal_loss=use_focal_loss,
    focal_loss_alpha=focal_loss_alpha,
    focal_loss_gamma=focal_loss_gamma,
    use_augmented=use_augmented,
    freeze_embeddings=freeze_embeddings,
    attention_bias=attention_bias,
    use_attention_aux=use_attention_aux,
    weight_decay=weight_decay,
    bias_init=bias_init,
    neg_splits=neg_splits,
    num_layers=num_layers,
    rnn_type=rnn_type,
    rnn_residual=rnn_residual,
    pooling_type=pooling_type,
    model_type=model_type,
    cache_elmo_embeddings=cache_elmo_embeddings,
    use_word_level_features=use_word_level_features,
    use_sentence_level_features=use_sentence_level_features,
    mixup_ratio=mixup_ratio,
    discrete_mixup_ratio=discrete_mixup_ratio,
    bucket=bucket,
    compute_thres_on_test=compute_thres_on_test,
    permute_sentences=permute_sentences,
    find_lr=find_lr,
    run_id=run_id,
)

# %%
from pathlib import Path

DATA_ROOT = Path("../data") / config.dataset

# %%
reader_registry = {}
def register(name: str):
    def dec(x: Callable):
        reader_registry[name] = x
        return x
    return dec

# %%
import gc, csv

from allennlp.data.fields import TextField, SequenceLabelField, LabelField, MetadataField, ArrayField
import string
alphabet = set(string.ascii_lowercase)

sentence_level_features: List[Callable[[List[str]], float]] = [
#     lambda x: (np.log1p(len(x)) - 3.628) / 1.065, # stat computed on train set
]

word_level_features: List[Callable[[str], float]] = [
    lambda x: 1 if (x.lower() == x) else 0,
    lambda x: len([c for c in x.lower() if c not in alphabet]) / len(x),
]

def proc(x: str) -> str:
    if "uncased" in config.model_type:
        x = x.lower()
    if config.model_type == "standard":
        return x.lower()
    else:
        return x

class MemoryOptimizedTextField(TextField):
    @overrides
    def __init__(self, tokens: List[str], token_indexers: Dict[str, TokenIndexer]) -> None:
        self.tokens = tokens
        self._token_indexers = token_indexers
        self._indexed_tokens: Optional[Dict[str, TokenList]] = None
        self._indexer_name_to_indexed_token: Optional[Dict[str, List[str]]] = None
        # skip checks for tokens
    @overrides
    def index(self, vocab):
        super().index(vocab)
        self.tokens = None # empty tokens

@register("jigsaw")
class JigsawDatasetReader(DatasetReader):
    def __init__(self, tokenizer: Callable[[str], List[str]]=lambda x: x.split(),
                 token_indexers: Dict[str, TokenIndexer] = None, # TODO: Handle mapping from BERT
                 max_seq_len: Optional[int]=config.max_seq_len) -> None:
        super().__init__(lazy=False)
        self.tokenizer = tokenizer
        self.token_indexers = token_indexers or {"tokens": SingleIdTokenIndexer()}
        self.max_seq_len = max_seq_len

    @overrides
    def text_to_instance(self, tokens: List[str], id: str,
                         labels: np.ndarray) -> Instance:
        sentence_field = MemoryOptimizedTextField([proc(x) for x in tokens],
                                   self.token_indexers)
        fields = {"tokens": sentence_field}
        
        wl_feats = np.array([[func(w) for func in word_level_features] for w in tokens])
        fields["word_level_features"] = ArrayField(array=wl_feats)
        
        sl_feats = np.array([func(tokens) for func in sentence_level_features])
        fields["sentence_level_features"] = ArrayField(array=sl_feats)

        label_field = ArrayField(array=labels)
        fields["label"] = label_field

        return Instance(fields)
    
    @overrides
    def _read(self, file_path: str) -> Iterator[Instance]:
        with open(file_path) as f:
            reader = csv.reader(f)
            next(reader)
            for i, line in enumerate(reader):
                if len(line) == 9:
                    _, id_, text, *labels = line
                elif len(line) == 8:
                    id_, text, *labels = line
                else: raise ValueError(f"line has {len(line)} values")
                yield self.text_to_instance(
                    self.tokenizer(text),
                    id_, np.array([int(x) for x in labels]),
                )
                if config.testing and i == 1000: break

# %%
from tqdm import tqdm
import warnings

def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')

def get_fasttext_embeddings(vocab: Vocabulary):
    prog_bar = tqdm(open(config.ft_model_path, encoding="utf8", errors='ignore'))
    prog_bar.set_description("Loading embeddings")
    embeddings_index = dict(get_coefs(*o.split(" ")) for o in prog_bar
                             if len(o)>100)
    all_embs = np.stack(embeddings_index.values())

    embeddings = np.zeros((config.vocab_size + 5, 300))
    n_missing_tokens = 0
    prog_bar = tqdm(vocab.get_index_to_token_vocabulary().items())
    prog_bar.set_description("Creating matrix")
    for idx, token in prog_bar:
        if idx == 0: continue # keep padding as all zeros
        if idx == 1: continue # Treat unknown words as dropped words
        if token == "[MASK]":
            embeddings[idx, :] = np.random.randn(300) * 0.5
        if token not in embeddings_index:
            n_missing_tokens += 1
            if n_missing_tokens < 10:
                warnings.warn(f"Token {token} not in embeddings: did you change preprocessing?")
            if n_missing_tokens == 10:
                warnings.warn(f"More than {n_missing_tokens} missing, supressing warnings")
        else:
            embeddings[idx, :] = embeddings_index[token]
    
    if n_missing_tokens > 0:
        warnings.warn(f"{n_missing_tokens} in total are missing from embedding text file")
    return embeddings

# %%
import random
from functools import wraps

def maybeshuffle(_tokenize):
    def func(*args, **kwargs):
        arr = _tokenize(*args, **kwargs)
        if config.permute_sentences:
            random.shuffle(arr)
        return arr
    return func

# %%
# Tokenizer and tokenizer index: THIS Is DIFFERENT FROM BERT!!!
token_indexer = SingleIdTokenIndexer(
    lowercase_tokens=True,
)
@maybeshuffle
def tokenizer(x: str):
    return [w.text for w in
            _spacy_tok(x)[:config.max_seq_len]]

# %%
reader = JigsawDatasetReader(
    tokenizer=tokenizer,
    token_indexers={"tokens": token_indexer}
)

# %%
train_ds, val_ds, test_ds = (reader.read(DATA_ROOT / fname) for fname in ["train_wo_val.csv",
                                                                          "val.csv",
                                                                          "test_proced.csv"])
# Out:
# 151592it [03:39, 689.59it/s]
# 7979it [00:09, 803.94it/s]
# 63978it [02:07, 502.77it/s]

# %%
full_ds = train_ds + val_ds + test_ds

# %%
from pytorch_pretrained_bert.tokenization import BertTokenizer

bert_tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

# %%
vocab = Vocabulary.from_instances(full_ds, max_vocab_size=config.max_vocab_size)
# Out:
# 100%|██████████| 223549/223549 [00:17<00:00, 12967.47it/s]

# %%
prog_bar = tqdm(vocab.get_index_to_token_vocabulary().items())
token_arr = [token for idx, token in prog_bar]
# Out:
# 100%|██████████| 305140/305140 [00:00<00:00, 2070197.50it/s]

# %%
config.set("vocab_size", min(vocab.get_vocab_size(), config.max_vocab_size))
config.set("embedding_dim", 300)
fasttext_embeds = get_fasttext_embeddings(vocab)
# Out:
# Loading embeddings: : 317458it [00:30, 10573.21it/s]
# /home/anna/neuralnlp/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   # This is added back by InteractiveShellApp.init_path()
# Creating matrix: 100%|██████████| 305140/305140 [00:01<00:00, 244141.01it/s]

# %%
from scipy.spatial.distance import cosine, euclidean
from numpy.linalg import norm
w1 = fasttext_embeds[vocab.get_token_index('fcuk')]
w2 = fasttext_embeds[vocab.get_token_index('fuck')]
print(np.sum(w1 * w2)/norm(w1)/norm(w2), 1 - cosine(w1, w2))
# Out:
# 0.38523468070826167 0.3852346807082616

# %%
'fcuk' in bert_tokenizer.vocab
# Out:
# False

# %%
bert_vocab_toks = bert_tokenizer.vocab.keys()
vocab_toks = set( [w for idx, w in vocab.get_index_to_token_vocabulary().items() ])

# %%
len(vocab_toks), len(bert_vocab_toks)
# Out:
# (305140, 30522)

# %%
bert_vocab_ids = []

for tok in bert_vocab_toks:
    tok_id = vocab.get_token_index(tok)
    if tok_id > 1:
        bert_vocab_ids.append(tok_id)
        
bert_vocab_ids = np.array(bert_vocab_ids)

# %%
fasttext_embeds[bert_vocab_ids].shape
# Out:
# (22778, 300)

# %%
import nmslib, time

M = 25
efC = 200

num_threads = 0
index_time_params = {'M': M, 'indexThreadQty': num_threads, 'efConstruction': efC, 'post' : 0}
print('Index-time parameters', index_time_params)
# Out:
# Index-time parameters {'M': 25, 'indexThreadQty': 0, 'efConstruction': 200, 'post': 0}

# %%
# Space name should correspond to the space name 
# used for brute-force search
space_name='cosinesimil'


# Intitialize the library, specify the space, the type of the vector and add data points 
index = nmslib.init(method='hnsw', space=space_name, data_type=nmslib.DataType.DENSE_VECTOR) 
index.addDataPointBatch(fasttext_embeds[bert_vocab_ids])
# Out:
# 22778

# %%
# Create an index
start = time.time()
index_time_params = {'M': M, 'indexThreadQty': num_threads, 'efConstruction': efC}
index.createIndex(index_time_params) 
end = time.time() 
print('Index-time parameters', index_time_params)
print('Indexing time = %f' % (end-start))
# Out:
# Index-time parameters {'M': 25, 'indexThreadQty': 0, 'efConstruction': 200}
# Indexing time = 4.890246

# %%
# Setting query-time parameters
efS = 1000
K=10
query_time_params = {'efSearch': efS}
print('Setting query-time parameters', query_time_params)
index.setQueryTimeParams(query_time_params)
# Out:
# Setting query-time parameters {'efSearch': 1000}

# %%
tok_id = vocab.get_token_index('fuuck')
query_arr = [fasttext_embeds[tok_id]]
query_matrix = np.array(query_arr)
K=10
query_matrix.shape, tok_id
# Out:
# ((1, 300), 100538)

# %%
# Querying
query_qty = query_matrix.shape[0]
start = time.time() 
nbrs = index.knnQueryBatch(query_matrix, k = K, num_threads = num_threads)
end = time.time() 
print('kNN time total=%f (sec), per query=%f (sec), per query adjusted for thread number=%f (sec)' % 
      (end-start, float(end-start)/query_qty, num_threads*float(end-start)/query_qty))
# Out:
# kNN time total=0.119758 (sec), per query=0.119758 (sec), per query adjusted for thread number=0.000000 (sec)

# %%
nbrs[0][0], nbrs[0][1]
# Out:
# (array([11084, 21732, 19477, 15291, 22556, 17013, 18107, 20259, 20725,
#         16667], dtype=int32),
#  array([0.47294343, 0.48340237, 0.4915681 , 0.50250036, 0.50813234,
#         0.509331  , 0.5209646 , 0.53238195, 0.5377827 , 0.53826004],
#        dtype=float32))

# %%
for i in nbrs[0][0]:
    print(vocab.get_token_from_index(bert_vocab_ids[i]))
# Out:
# ninja
# minions
# yuki
# ryu
# gunslinger
# akira
# sakura
# mikey
# godzilla
# knocks

# %%
oov_toks = vocab_toks - bert_vocab_toks
query_arr = []
query_toks = []
for tok in oov_toks:
    tok_id = vocab.get_token_index(tok)
    query_arr.append(fasttext_embeds[tok_id])
    query_toks.append(tok)
    
query_matrix = np.array(query_arr)
query_matrix.shape
# Out:
# (282362, 300)

# %%
# Setting query-time parameters
efS = 1000
K=10
query_time_params = {'efSearch': efS}
print('Setting query-time parameters', query_time_params)
index.setQueryTimeParams(query_time_params)
# Out:
# Setting query-time parameters {'efSearch': 1000}

# %%
# Querying
query_qty = query_matrix.shape[0]
start = time.time() 
nbrs = index.knnQueryBatch(query_matrix, k = K, num_threads = num_threads)
end = time.time() 
print('kNN time total=%f (sec), per query=%f (sec), per query adjusted for thread number=%f (sec)' % 
      (end-start, float(end-start)/query_qty, num_threads*float(end-start)/query_qty))
# Out:
# kNN time total=236.377475 (sec), per query=0.000837 (sec), per query adjusted for thread number=0.000000 (sec)

# %%
OOV_THRESHOLD=0.3 # We care only about very similar items
oov_map = dict()

for i in range(query_qty):
    nbr_ids = nbrs[i][0]
    nbr_dist = nbrs[i][1]
    query_tok = query_toks[i]
    
    for k in range(len(nbr_ids)):
        nbr_id = nbr_ids[k]
        tok_id = bert_vocab_ids[nbr_id]
        nbr_tok = vocab.get_token_from_index(tok_id)
        assert(query_tok != nbr_tok)
        if nbr_dist[k] <= OOV_THRESHOLD:
            oov_map[query_tok] = nbr_tok
            break

# %%
oov_map
# Out:
# {'matsueda': 'takahashi',
#  'appropriate?==': 'appropriate',
#  'q.theory': 'theory',
#  'radiography': 'imaging',
#  'http://en.wikipedia.org/w/index.php?title=wikipedia%3aadministrators%27_noticeboard%2fincidents&diff;=74800280&oldid;=74797250': 'php',
#  'undermines': 'undermine',
#  'مع': 'ـ',
#  'detectable': 'detect',
#  'conquerors': 'conquest',
#  'migraine': 'headache',
#  'http://www.geocities.com/ancientcoinsofindia/norksh1.htm': '0',
#  'serbiab': 'serbia',
#  'rapcore': 'thrash',
#  'swears': 'confesses',
#  'parenchyma': 'tissue',
#  'milanese': 'italian',
#  'phrasing""tightened': 'tightened',
#  'isawesome': 'awesome',
#  'thiazolidinedione': 'methyl',
#  'miklós': 'hungarian',
#  '|heritage': 'heritage',
#  'сообщества': 'и',
#  'прогрессивные': 'и',
#  'english?': 'english',
#  'http://en.wikipedia.org/w/index.php?title=user_talk:whispertome&diff;=cur': 'php',
#  'wissenschaftlichen': 'geschichte',
#  'swetha': 'lakshmi',
#  'visayas': 'mindanao',
#  'hawkertyphoon': 'typhoon',
#  'http://www.p2pfoundation.net/transfinancial_economics': '0',
#  'islamofascism': 'fascism',
#  'triangles)it': 'triangles',
#  'appendixes': 'appendix',
#  'relevations': 'elevations',
#  'http://www.thefreelibrary.com/football%3a+goals+are+on+the+menu+for+hot+pan%3b+walter+pandiani+is...-a0136330778': '0',
#  'nürnberg': 'nuremberg',
#  'quotation(s': 'quotes',
#  'experimentally': 'experiments',
#  'perches': 'perch',
#  'topographies': 'topography',
#  '71641': '1641',
#  'administrators|21': 'administrators',
#  'serotoninergic': 'receptor',
#  "d'histoire": 'histoire',
#  'otherwise-': 'otherwise',
#  'protrude': 'protruding',
#  '|historical': 'historical',
#  'exposured': 'exposure',
#  'pseudonymns': 'pseudonym',
#  'hemisphere?•': 'hemisphere',
#  'алматы': 'и',
#  'azithromycin': 'antibiotics',
#  'unsubtle': 'subtle',
#  'finalize': 'finalized',
#  'ismailis': 'sunni',
#  'narasimha': 'lakshmi',
#  'ramadi': 'isil',
#  'abdelaziz': 'mohamed',
#  'হয়ে': 'এ',
#  'https://catalyst.library.jhu.edu/?commit=search&f;%5bauthor_facet%5d%5b%5d=zhang%2c+mu%2c+1805-1849&f;%5bdiscipline_facet%5d%5b%5d=world+history&f;%5blanguage_facet%5d%5b%5d=chinese&f;%5blocation_facet%5d%5b%5d=msel+special+collections&q;=&search;_field=all_fields': '0',
#  'endovascular': 'vascular',
#  'gabapentin': 'medications',
#  'clunky': 'awkward',
#  'phightins': 'utc',
#  'società': 'italiana',
#  'hesitations': 'hesitation',
#  'recompute': 'compute',
#  'oaths': 'oath',
#  'captureka': 'capture',
#  'annoyances': 'annoyance',
#  'precident': 'precedent',
#  'concurred': 'disagreed',
#  'appologize': 'apologize',
#  'lezion': 'aviv',
#  'singapore|': 'singapore',
#  'достатньою': 'и',
#  'izetbegović': 'bosnian',
#  'explorations': 'exploration',
#  'biologiebüchern': 'und',
#  'были': 'и',
#  '-purposely': 'purposely',
#  'preservationist': 'preservation',
#  'http://www.humboldt.edu/~ccat/drupal-5/index.php/': 'www',
#  'المال.': 'و',
#  'liguistic': 'linguistic',
#  'искать': 'и',
#  'organophosphorus': 'phosphorus',
#  'blueish': 'greenish',
#  'thistles': 'thistle',
#  'misunderstandnings': 'misunderstanding',
#  'na+/k+-atpase': 'proteins',
#  'baptiste.,la': 'baptiste',
#  'rematching': 'rematch',
#  'contaminated.[65': 'contaminated',
#  'korsakov': 'tchaikovsky',
#  'просьба': 'и',
#  'judgemts': 'judgement',
#  'verbs,(or': 'verbs',
#  'forehead*.': 'forehead',
#  'haruno': 'sakura',
#  'ceasefires': 'ceasefire',
#  'offensiv': 'offensive',
#  'leben': 'eine',
#  'использовались': 'и',
#  'tmplate': 'template',
#  'belorussian': 'belarusian',
#  'socrate': 'socrates',
#  'holocausts': 'holocaust',
#  'adminitsrators': 'administrators',
#  'yamuna': 'ganga',
#  'salads': 'salad',
#  'दर्शाता': 'न',
#  'büyükada': 'istanbul',
#  'sub)tropical': 'tropical',
#  'enquiry': 'inquiry',
#  'abbrevs': 'abbreviation',
#  'http://mongomutter.blogspot.com/2005/07/calling-londonistan-its-time-to-wake.html': '159',
#  'ulster.or': 'ulster',
#  'someonetm': 'someone',
#  'geodesics': 'euclidean',
#  'http://www.codeproject.com/kb/architecture/oop_concepts_and_manymore.aspx': '0',
#  'hokkai': 'hokkaido',
#  'pussy.u': 'pussy',
#  'التماس': 'و',
#  'во': 'и',
#  'olympique': 'ligue',
#  'quantitively': 'quantities',
#  'suppertime': 'supper',
#  'categoriesi': 'categories',
#  'http://en.wikipedia.org/w/index.php?title=wikipedia:administrators%27_noticeboard/incidents&diff;=next&oldid;=533790956': 'php',
#  'evict': 'evicted',
#  'boliviano': 'bolivian',
#  'cyclosporines': 'antibiotics',
#  'sassanid': 'persians',
#  'submitters': 'submitted',
#  'rework': 'reworked',
#  'reestablishment': 'establishment',
#  'replications': 'replication',
#  'headwater': 'headwaters',
#  'tamla': 'motown',
#  'ambrogio': 'pietro',
#  'independence;fought': 'independence',
#  '|archive': 'archive',
#  'http://www.pressplus1.com/music/press-release-new-kids-new-tour-new-album.html': 'www',
#  'doorstepping': 'doorstep',
#  'walthamstow': 'croydon',
#  'misrepresenting': 'misleading',
#  'xingdong': 'guangdong',
#  'conspirancy': 'conspiracy',
#  'डकार': 'व',
#  'huskie': 'huskies',
#  'meiner': 'eine',
#  'fostering': 'encouraging',
#  'http://www.officialcharts.com/': '0',
#  'airlplanes': 'aircraft',
#  'tsai': 'cheng',
#  'coincidently': 'coincidence',
#  '4-paragraph': 'paragraph',
#  'consequenceshu12': 'consequences',
#  'http://www.worstpreviews.com/headline.php?id=5620&count;=0': '0',
#  'undiscouraged': 'discouraged',
#  'snorting': 'snorted',
#  'gambrel': 'gabled',
#  'motherfuckerdie': 'fuck',
#  'retrotransposons': 'rna',
#  'gradient==': 'gradient',
#  'conspiring': 'conspiracy',
#  'remorseless': 'remorse',
#  'declaration.ogg': 'declaration',
#  'championship#final': 'championship',
#  'hirotaka': 'takahashi',
#  'orchestrator': 'arranger',
#  'provinc': 'province',
#  'background:#dcdcdc': 'background',
#  'physiologie': 'physiological',
#  'based(platforming': 'platforms',
#  'rajeshmsharma': 'sharma',
#  'countesses': 'countess',
#  'http://blog.newenergytimes.com/2011/06/20/galantini-sends-e-mail-about-rossi-steam-measurements-today/': '0',
#  'inwards': 'inward',
#  'bismarcks': 'bismarck',
#  'nor#terminology': 'terminology',
#  'arbcoms': 'arbitration',
#  'espinosa': 'ortega',
#  'misinterpretations': 'interpretations',
#  'مورد': 'ـ',
#  'cunts': 'fucking',
#  'consecrators': 'archbishop',
#  'rebellion-': 'rebellion',
#  '04:10': '510',
#  'http://en.wikipedia.org/w/index.php?title=afghan_post&oldid;=483771210': 'php',
#  'discharged"",he': 'discharged',
#  'таблицата': 'и',
#  'copyrights': 'copyright',
#  'complaint==': 'complaint',
#  'wheelpassengers01.jpg': 'passenger',
#  'repositories': 'repository',
#  'говорить': 'в',
#  'ritualized': 'ritual',
#  'compliment!yamla': 'compliment',
#  'carpatho': 'carpathian',
#  '|politics': 'politics',
#  'http://www.financa.gov.al/files/userfiles/programimi_ekonomikofiskal/kuadri_makroekonomik_dhe_fiskal/kmf_periudhen_2014-2016_vkm_nr.73_date_23.01.2013.pdf': '0',
#  'microsoft-watch.com': 'microsoft',
#  'پيامبران': 'و',
#  'feeedback': 'feedback',
#  'entrepreneurship-': 'entrepreneurship',
#  'https://www.youtube.com/watch?v=jg7vhmmxagq': 'youtube',
#  'puthiya': 'malayalam',
#  'vesicles': 'membrane',
#  'chocolateroar': 'chocolate',
#  'vehement': 'outspoken',
#  'كوردستان': 'و',
#  'safeguards': 'safeguard',
#  'hellenious': 'hellenistic',
#  'genocides': 'genocide',
#  'opioids': 'medications',
#  'händel': 'handel',
#  'palace(s': 'palace',
#  'conciseness': 'clarity',
#  'florentine': 'medici',
#  'velvets': 'velvet',
#  'auffassung': 'und',
#  'الوفاء': 'ـ',
#  'deutschlandlied': 'deutschland',
#  'senna': 'schumacher',
#  'المرض': 'ـ',
#  'agency==': 'agency',
#  'jacopo': 'francesco',
#  'http://arxiv.org/pdf/1303.0614v1.pdf': 'pdf',
#  'germany´s': 'germany',
#  'magnetism': 'magnetic',
#  'upleasant': 'pleasant',
#  'iceland.co.uk': 'iceland',
#  'bridgwater': 'taunton',
#  'understandble': 'understand',
#  'pestilence': 'plague',
#  'thanks!|ck': 'thanks',
#  'plantation==': 'plantations',
#  'library?some': 'library',
#  'ال': 'و',
#  'fluffybun': 'fluffy',
#  'tennessee)#archaeological': 'archaeological',
#  'wikisyntax': 'syntax',
#  'evgeniy': 'sergey',
#  'http://www.boston.com/news/nation/articles/2007/12/27/mccains_children_avoid_the_limelight/': '0',
#  'desktopx': 'desktop',
#  'http://wiki.answers.com/q/what_is_the_definition_of_hazel_eyes': '0',
#  'menschlichkeit': 'und',
#  'lenders': 'mortgage',
#  'rituparna': 'mukherjee',
#  'passageways': 'passageway',
#  'surfactants': 'solvent',
#  'effortlessness': 'effortlessly',
#  'dinoflagellate': 'algae',
#  'travaux': 'histoire',
#  'k.fmjdhasgthujgfydszvfgyuihugytfdrtyghijkhgfgnhjmutrdesedfgyuiytrdgfnoiuytihugyftdrtftfkyghyduysgcbyuhjhhhhhhhhhhgbhjuggufyafgvwaygeufvbt6yawstdygujimaqzwerstdgyuhnjmkrlgfthyjuidfcgvhjbnkmlfdgrchujwazsexdrcftgvyhunjwazesrdtgfybhujimkszxdgfvhjnmkl': '159',
#  '26/murder': 'murder',
#  'fuckkk': 'fuck',
#  'criminal,2015.jpg': 'criminal',
#  'subside': 'subsided',
#  'mainland=': 'mainland',
#  'propell': 'propelled',
#  'languageie': 'language',
#  'mythology|aesir': 'mythology',
#  'diadvantage': 'advantages',
#  'https://en.wikipedia.org/w/index.php?title=jacob_o._meyer&oldid;=608190095': 'php',
#  'bitch.': 'bitch',
#  'http://en.wikipedia.org/w/index.php?title=the_citadel,_the_military_college_of_south_carolina&oldid;=298694103': '1837',
#  'assistance_publique_-_hôpitaux_de_paris': '1837',
#  'apolitical': 'politically',
#  'статей': 'и',
#  'represed': 'represent',
#  'refocusing': 'focusing',
#  'shao': 'liu',
#  'про': 'и',
#  'permissible': 'permitted',
#  'continuo': 'violins',
#  'amide': 'methyl',
#  'xenobiotics': 'metabolism',
#  'http://en.wikipedia.org/w/index.php?title=fidelity_%28house%29&action;=purge': 'php',
#  'business-': 'business',
#  'германн': 'в',
#  'sailboat': 'sailing',
#  'martialed': 'acquitted',
#  'русского.': 'и',
#  'clergyman)==': 'clergyman',
#  'forebears': 'ancestors',
#  'الاحتلال': 'و',
#  'overexaggerated': 'exaggerated',
#  'trought': 'trough',
#  'analyticity': 'analytic',
#  'novomoskovsk': 'oblast',
#  'http://www.talentondisplay.com/girls/jadinwong.jpg': '0',
#  'recommending': 'recommended',
#  'knifes': 'knife',
#  'gesehen': 'und',
#  'http://www.opsi.gov.uk/si/si2008/draft/ukdsi_9780110806570_en_1': '0',
#  'importancethis': 'importance',
#  'сабат': 'и',
#  'المروية،': 'و',
#  'вооруженным': 'и',
#  'bibhutibhushan': 'narayan',
#  'بالاخره': 'ـ',
#  'yearned': 'longed',
#  '-seriously': 'seriously',
#  'jogendranath': 'mukherjee',
#  'complaints-': 'complaints',
#  'الاوضاع': 'و',
#  'restarts': 'restart',
#  'twiced': 'twice',
#  'kroatischen': 'geschichte',
#  'ibadi': 'sunni',
#  'عليها': 'ـ',
#  'http://www.keywordcompanion.com/keywords_conversion_continuity.html': '0',
#  'width=120|philippine': 'philippine',
#  'löschanträge': 'und',
#  'converging': 'converge',
#  'hassani': 'hassan',
#  'luthor': 'superman',
#  'khān': 'romanized',
#  'figures-': 'figures',
#  'rarity': 'rare',
#  'discussing-': 'discussing',
#  'aeroplane': 'airplane',
#  'ludvig': 'henrik',
#  'herausgenommen': 'und',
#  'arvind': 'prakash',
#  'disappointingly': 'disappointing',
#  'sockfarm': 'sock',
#  'стать': 'и',
#  'inaugurate': 'inaugurated',
#  'nuova': 'della',
#  'дон': 'и',
#  'temporaly': 'temporal',
#  'raccoons': 'squirrels',
#  'pelycosaurs': 'dinosaurs',
#  'minaj': 'rihanna',
#  'not#journalism': 'journalism',
#  'eritrea.jpg': 'eritrea',
#  'anyone.talk': 'anyone',
#  'krestetsky': 'oblast',
#  'solutios': 'solution',
#  "l'derry": 'derry',
#  'terminolology': 'terminology',
#  'utkarshraj': 'pandit',
#  'oxidizer(electron': 'electron',
#  '17.73': '173',
#  'uruguayo': 'uruguay',
#  'language==': 'language',
#  'iranian(not': 'iranian',
#  'verfassung': 'geschichte',
#  '0-vectors': 'vectors',
#  'federalism': 'liberalism',
#  'festooned': 'adorned',
#  'вјерна': 'и',
#  'utc350.122530': '122',
#  'liqueur': 'vodka',
#  'располагалась': 'и',
#  'episode?.the': 'episode',
#  'ncaas': 'ncaa',
#  'background:#9bb998': 'background',
#  'wearin': 'wearing',
#  "revert'd": 'reverted',
#  'transjordan': 'palestine',
#  'подвести': 'и',
#  'lobule': 'posterior',
#  'reciters': 'recited',
#  '~introduction': 'introduction',
#  'unsystematic': 'systematic',
#  'fri': 'wed',
#  'complicates': 'complicated',
#  'resold': 'sold',
#  'gtchannel': 'channel',
#  'violationhe': 'violation',
#  'adverb': 'verb',
#  'stitching': 'stitch',
#  'relegating': 'relegated',
#  'cystathionine': 'enzyme',
#  'blenheim': 'marlborough',
#  'happent': 'happen',
#  'http://worldimprover.net/en/en8.html': 'www',
#  'imitates': 'imitation',
#  'вынес': 'б',
#  'mulder': 'scully',
#  'design==': 'design',
#  'multiprocessor': 'processor',
#  'http://en.wikipedia.org/w/index.php?title=user_talk:illyukhina&action;=history': 'php',
#  'semitic.the': 'semitic',
#  'shudder!.': 'shudder',
#  'http://www.orwelltoday.com/jfkcoincidences.shtml': '0',
#  'adjusted/""retyped': 'adjusted',
#  'ocument.editform.wpsave.addeventlistener(""click': '0',
#  'terrorist==': 'terrorist',
#  'cartoons.[2': 'cartoon',
#  'hallucination': 'amnesia',
#  'aufbruch': 'eine',
#  'bp-1227': '122',
#  'الجنود': 'ـ',
#  'amusements': 'amusement',
#  'slaying': 'slain',
#  'swabians': 'hungarians',
#  'parvanov': 'ivanov',
#  'http://en.wikipedia.org/wiki/people_of_the_sengoku_period_in_popular_culture#hattori_hanz.c5.8d': '1837',
#  'kurdin': 'kurdish',
#  'underminds': 'undermine',
#  'pickens': 'calhoun',
#  'discovery==': 'discovery',
#  'rybakov': 'andrey',
#  'efficency': 'efficiency',
#  'lobsters': 'lobster',
#  'rodential': 'rodents',
#  'savoury': 'dessert',
#  'similarit': 'similarity',
#  'obstinate': 'stubborn',
#  'circulations': 'circulation',
#  'clenches': 'clenched',
#  'wheelspin': 'wheels',
#  'essonne': 'marne',
#  'languages)useful': 'languages',
#  'schizotypal': 'schizophrenia',
#  'مصداقية': 'ـ',
#  'disputed][citation': 'disputed',
#  'insisnt': 'insisting',
#  'حافظ': 'ـ',
#  'beispielsweise': 'eine',
#  'применение.': 'и',
#  'yoritomo': 'tokugawa',
#  'descendandts': 'descendants',
#  'принадлежит': 'и',
#  'harvest.-': 'harvest',
#  'citv': 'itv',
#  'apologets': 'apologetic',
#  'pigmentation': 'pigment',
#  'вел': 'и',
#  'all.""(emphasis': 'emphasis',
#  'spontanously': 'spontaneously',
#  'tensors': 'tensor',
#  'огород': 'и',
#  '-planting': 'planting',
#  'spermatozoon': 'sperm',
#  'aticle': 'article',
#  'srinivasulu': 'rao',
#  'sanctioning': 'sanctioned',
#  'electrodynamics#mergefrom': 'equations',
#  'nonexistent': 'existent',
#  'व्यवस्था': 'व',
#  'dermatology': 'pediatric',
#  'https://card.ml.com/mlrewardscenter/beyondrewardsviewcatalog.htm?oc_cc=bb00icc&oc;_ac=000bb&oc;_ref=mlcaff&oc;_loc=05': '0',
#  'guatemalamission.jpg': 'guatemala',
#  'deleteda': 'deleted',
#  'unquestionably': 'undoubtedly',
#  'billion=': 'billion',
#  'http://www.animenewsnetwork.com/encyclopedia/anime.php?id=12216&page;=25': '0',
#  'rubbish==': 'rubbish',
#  'http://fusion.erau.edu/ec/wwc/centerinfo.cfm?code=02': '0',
#  'secularism': 'liberalism',
#  'satisfyed': 'satisfy',
#  'srirangam99': 'mysore',
#  'bartolomei': 'battista',
#  'могли': 'и',
#  'subsets': 'subset',
#  'safavids': 'caliphate',
#  'hinduisms': 'hinduism',
#  'translation#how': 'translations',
#  'rugeley': 'staffordshire',
#  'urogenital': 'cervical',
#  'macronutrient': 'nutrient',
#  "wikipedia'ism": 'wikipedia',
#  'uzbek': 'kazakh',
#  'порой': 'и',
#  'reinterpreting': 'interpreting',
#  'rhetorically': 'rhetoric',
#  'trotskyites': 'communist',
#  'aggressors': 'aggression',
#  'abhijeet': 'sharma',
#  'willamette': 'oregon',
#  'senegambian': 'senegal',
#  'legnica': 'wrocław',
#  'safin': 'federer',
#  'republican!!!go': 'republican',
#  'wuxi': 'jiangsu',
#  'coils': 'coil',
#  'http://en.wikipedia.org/w/index.php?title=tanks_%281919-1939%29&oldid;=40928499': 'php',
#  'harass?': 'harassed',
#  'felons': 'offenders',
#  'beschriftung': 'geschichte',
#  "video's": 'video',
#  'nutrality': 'neutrality',
#  'mazhavarayas': 'nadu',
#  'guidelinesfrequently': 'guidelines',
#  'beethoven#infobox': 'beethoven',
#  'dictating': 'dictated',
#  'nationality==': 'nationality',
#  'urethra': 'bladder',
#  'rhwentworth': 'wentworth',
#  'hyperinflationary': 'inflation',
#  'eleverything': 'everything',
#  'ru:обрезание': 'в',
#  'fucktard': 'asshole',
#  'suppresed': 'suppression',
#  'updated(by': 'updated',
#  'myung': 'hyun',
#  'benthic': 'invertebrates',
#  'vedantic': 'vedic',
#  'know#christmas': 'christmas',
#  'documentations': 'documentation',
#  'arrogancy': 'arrogance',
#  'mucormycoses': 'infections',
#  'learnign': 'learning',
#  '1778–81': '1778',
#  'funmobility': 'mobility',
#  'году.': 'и',
#  'acoustically': 'acoustic',
#  'citeability': 'reliability',
#  'http://www.erowid.org/references/refs_view.php?a=showdocpartframe&id;=6513&docpartid;=6040': '0',
#  'redirected': 'merge',
#  'rawalpindi': 'lahore',
#  'negligence.130.17.92.17': 'negligence',
#  'का': 'न',
#  'group=': 'group',
#  'television==': 'television',
#  '|richmond': 'richmond',
#  'speculation)==': 'speculation',
#  'philosophy.rutgers.edu': 'philosophy',
#  'reviews==': 'reviews',
#  'waffen': 'wehrmacht',
#  'functionalist': 'modernist',
#  'andalusia': 'spain',
#  'utr': 'rna',
#  'ɖ': 'ʋ',
#  'compactification': 'topological',
#  'practises': 'practised',
#  'obstetrics': 'pediatric',
#  'indexes': 'indices',
#  'group\u200f': 'group',
#  'http://i.imgur.com/txc3j0n.jpg': '0',
#  'flavorless': 'flavor',
#  'launderer': 'laundering',
#  'cartoony': 'cartoon',
#  'dendrologist': 'botanist',
#  'insofar': 'fundamentally',
#  'semicircular': 'arched',
#  'https://en.wikipedia.org/w/index.php?title=meir_kahane&diff;=626285820&oldid;=626285052': 'php',
#  'foundation-': 'foundation',
#  'yvelines': 'marne',
#  'http://www.thenews.com.pk/todaysprintdetail.aspx?id=45320&cat;=5&dt;=5/6/2011': '0',
#  'escutcheon': 'argent',
#  'cultivates': 'cultivated',
#  'adolescence.[2][1': 'adolescence',
#  'awfully': 'terribly',
#  'chairmen': 'chairman',
#  'community(with': 'community',
#  'officerf&s': 'officer',
#  'laureates': 'nobel',
#  'schematology': 'pathology',
#  'comprehensives': 'comprehensive',
#  'tralee': 'limerick',
#  'reptile?==': 'reptiles',
#  'townsfolk': 'townspeople',
#  'insomnia': 'nausea',
#  'redefine': 'define',
#  'mesothelioma': 'cancers',
#  'خادمیان': 'ـ',
#  'languages#mass': 'languages',
#  'enraging': 'enraged',
#  'subspaces': 'topological',
#  'renin)|receptor': 'receptor',
#  'राजपुरा': 'न',
#  'tambourine': 'percussion',
#  'الملقبة': 'ـ',
#  'winner""': 'winners',
#  'formulate': 'formulated',
#  'boast': 'boasts',
#  'akkadian': 'babylonian',
#  'transpires': 'realises',
#  'israel==': 'israel',
#  'precedings': 'preceding',
#  'uncomfortable.74.192.7.135': 'uncomfortable',
#  'demographers': 'demographic',
#  'syncing': 'sync',
#  'protester': 'protesters',
#  'kaohsiung': 'taipei',
#  'philosophische': 'geschichte',
#  'subscribing': 'subscribers',
#  'crushes': 'crush',
#  '2-litre': 'litre',
#  'secessionist': 'secession',
#  'edison==': 'edison',
#  'ziyi': 'xiang',
#  'aoi': 'sakura',
#  'manhattans': 'manhattan',
#  'pertains': 'pertaining',
#  'ignorance-': 'ignorance',
#  'facilitation': 'facilitating',
#  'الجمهوريات': 'ـ',
#  'readers.2': 'readers',
#  'electrolriagnetic': 'magnetic',
#  'itconcerning': 'concerning',
#  'accommodates': 'accommodated',
#  'orientals': 'oriental',
#  'angrynintendo': 'nintendo',
#  'exposes': 'expose',
#  'predictably': 'predictable',
#  'argument.s': 'arguments',
#  'continues.—': 'continues',
#  'inaccessable': 'inaccessible',
#  'scholars,[1': 'scholars',
#  'nonselective': 'selective',
#  'sighter': 'sighted',
#  'hyperactivity': 'disorders',
#  'trolled': 'troll',
#  'اللون': 'و',
#  'justifiy': 'justification',
#  'melbourne4ever': 'melbourne',
#  'गर्ने': 'न',
#  'denominaton': 'denomination',
#  'virology': 'biochemistry',
#  'oooh': 'yeah',
#  'olof': 'fredrik',
#  'dracula918': 'dracula',
#  'mozaffar': 'reza',
#  '|biography': 'biography',
#  'pythonic': 'python',
#  'blacken': 'blackened',
#  'tubercle': 'posterior',
#  'inconstructive': 'constructive',
#  'drogheda': 'limerick',
#  'पाकिस्तान': 'व',
#  'більше': 'в',
#  'meaninglessness': 'meaningless',
#  'nacionalist': 'nationalist',
#  'المتمثل': 'و',
#  'selectivity': 'selective',
#  'utilising': 'utilizing',
#  'pragmatischen': 'geschichte',
#  'الطويلة': 'و',
#  'aircraft#requested': 'aircraft',
#  'scuttling': 'sinking',
#  'washington,[2][3': 'washington',
#  'downpours': 'rains',
#  '122.106.14.163': '122',
#  'spokeswoman': 'spokesperson',
#  'herrings': 'herring',
#  'си': 'и',
#  'mails': 'emails',
#  'toxin==': 'toxin',
#  'napkins': 'napkin',
#  'http://www.londonnet.co.uk/listings/healthbeauty/dentists/hkleidentalsurgeryinstepney/': '0',
#  'takami': 'tanaka',
#  'butchers': 'butcher',
#  'buddhologists': 'psychologists',
#  'picosecond': 'pulsed',
#  'unclenched': 'clenched',
#  'arbitratiom': 'arbitration',
#  'evidence’': 'evidence',
#  'mdupont': 'dupont',
#  'accrington': 'stockport',
#  'sponges': 'sponge',
#  'करत': 'र',
#  'rashidi': 'rashid',
#  'disgracefully': 'disgrace',
#  '376': '37',
#  'dyskinesia': 'dysfunction',
#  'ningxiared': 'hunan',
#  'polypeptides': 'peptide',
#  'gilan': 'kerman',
#  'thread(s': 'threads',
#  'kinesiologist': 'psychologist',
#  'согласно': 'и',
#  'abbottabad': 'peshawar',
#  'pham': 'nguyen',
#  'помогут': 'и',
#  'heterozygosity': 'mutations',
#  'professiona': 'professional',
#  'duller': 'darker',
#  'afghanistand': 'afghanistan',
#  'rdbms': 'sql',
#  'chetan': 'kumar',
#  'templatespace': 'template',
#  'beguilingly': 'delightful',
#  'discuss|': 'discuss',
#  'tibetan)as': 'tibetan',
#  'skeletals': 'skeletal',
#  'markiewicz': 'stanisław',
#  'alleviates': 'alleviate',
#  'http://www.time.mk/c/61e6ad16de/janev-postoi-praven-lek-za-imeto.html': '0',
#  'homs': 'aleppo',
#  'anjaan': 'bollywood',
#  'fileservers': 'servers',
#  'سروسامان': 'ـ',
#  'sirpur': 'patna',
#  'festive': 'festivities',
#  'slizard': 'lizard',
#  'alcohol_and_cancer#sentence_logic': '1837',
#  'undoubtable': 'undoubtedly',
#  'reputaton': 'reputation',
#  'wikiportals': 'portals',
#  'understood-': 'understood',
#  '1-vectors': 'vectors',
#  '5-hydroxytryptamine': 'methyl',
#  'является': 'и',
#  'applauding': 'praising',
#  'freelancing': 'freelance',
#  'truncates': 'truncated',
#  'biomembranes': 'membranes',
#  'विशिष्ट': 'न',
#  'hypochlorite': 'chloride',
#  'balipatna': 'patna',
#  'स्थित': 'व',
#  'archeologists': 'archaeologists',
#  'brandenburger': 'brandenburg',
#  'seaplanes': 'aircraft',
#  'sockpupptry': 'sock',
#  'landslidey': 'landslide',
#  'damburger': 'hamburger',
#  'http://www.humboldt.edu/~ere_dept/undergrad/program.php': '0',
#  'pyrenees33': 'pyrenees',
#  'buddhadharma': 'buddha',
#  'chemists': 'chemist',
#  'году': 'и',
#  'noncommercially': 'commercially',
#  'https://en.wikipedia.org/w/index.php?title=israel&diff;=657360828&oldid;=657331946': 'php',
#  'कान': 'र',
#  'http://en.wikipedia.org/w/index.php?title=bench_press&direction;=next&oldid;=5794667': 'php',
#  'модернизированный': 'и',
#  'refuelling': 'refueling',
#  'slanders': 'accusations',
#  'cornmeal': 'roasted',
#  '20||tottenham': 'tottenham',
#  'comics’': 'comics',
#  '|napoleonic': 'napoleonic',
#  'sock==': 'sock',
#  'hessitated': 'necessitated',
#  'kodokan': 'judo',
#  'http://www.heraldica.org/topics/france/frflag.htm#tricolor': 'www',
#  'download)http://itunes.apple.com': 'download',
#  'cuticles': 'tissues',
#  'agronomic': 'agricultural',
#  'exoplanetaryscience': 'planetary',
#  'sockpuppetl': 'sock',
#  '-procedure': 'procedure',
#  'http://www.pwc.com/en_us/us/issues/ifrs-reporting/publications/assets/pwc-ifrs-by-country-2014.pdf': 'www',
#  'freezer': 'refrigerator',
#  'anywher': 'anywhere',
#  'intimidatory': 'intimidating',
#  'provincinal': 'provincial',
#  'anyway?tim': 'anyway',
#  'prabhupāda': 'swami',
#  'mules': 'horses',
#  'injection,169.139.19.174': 'injection',
#  'mekayla': 'kayla',
#  'rugby-': 'rugby',
#  'expirenced': 'expired',
#  'spymagician': 'magician',
#  'factorials': 'integers',
#  'donning': 'wearing',
#  'http://judicial.coolpage.biz/123polanski_another_child_drugs.htm': '0',
#  'dissimilation': 'assimilation',
#  'dhenkanal': 'odisha',
#  'chhatarpur': 'madhya',
#  'caterpillars': 'larvae',
#  'sopyright': 'copyright',
#  'stoichiometric': 'oxidation',
#  'lenses.jpg': 'lenses',
#  '|dutch': 'dutch',
#  'subcontracted': 'contractors',
#  'almight': 'almighty',
#  'поактивните': 'и',
#  'purges': 'purge',
#  'dissappointed': 'disappointed',
#  'helmand': 'afghanistan',
#  'специалистов': 'и',
#  'montenenegro': 'montenegro',
#  'webinars': 'seminars',
#  'hellenize': 'hellenistic',
#  'ahmadis': 'muslims',
#  'pussy6': 'pussy',
#  'hulagu': 'mongols',
#  'embarassed': 'embarrassed',
#  'http://www.bluepoppy.com/press/download/press_articles.cfm': 'www',
#  'tauranga': 'auckland',
#  'condescent': 'sarcastic',
#  'infinity88': 'infinity',
#  'inrconvert': 'convert',
#  'اسرائيلية': 'ـ',
#  'theologiae': 'theology',
#  'acommodate': 'accommodate',
#  'prabhākara': 'sanskrit',
#  'eligibilty': 'eligibility',
#  'поздравче': 'о',
#  'uraufführung': 'und',
#  'paradigmatically': 'paradigm',
#  'mythologies==': 'mythology',
#  'rathore': 'singh',
#  'tragics': 'tragic',
#  'kampfgruppe': 'panzer',
#  'climber': 'climbing',
#  'thearchaeologist': 'archaeologist',
#  'zhan': 'zhang',
#  'mineshafts': 'shafts',
#  'mediocre': 'disappointing',
#  'stourbridge': 'wolverhampton',
#  "controversies'#systemic": 'controversies',
#  'carbine': 'rifle',
#  'subgenre': 'genre',
#  'invalidating': 'invalid',
#  'quivers': 'quiver',
#  'http://www.independent.co.uk/news/people/therainbowlist/rainbow-list-2014-ones-to-watch-internationals-power-couples-and-straight-allies-9848534.html': '0',
#  'manslaughter': 'convicted',
#  'maseratti': 'ferrari',
#  'aetheist': 'atheist',
#  'bribing': 'bribe',
#  'foxsports.com': 'espn',
#  'dentists': 'physicians',
#  'unappealing': 'appealing',
#  'κρήτη': 'ο',
#  'goldman60': 'goldman',
#  'http://en.wikipedia.org/w/index.php?title=nissan_gt-r&action;=history': 'php',
#  'त्यासाठी': 'এ',
#  'türkic': 'turkic',
#  'candidates|list': 'candidates',
#  'ssunglasses': 'sunglasses',
#  'believe"".they': 'believe',
#  'authorizes': 'authorized',
#  'carlsson': 'andersson',
#  'redistributed': 'redistribution',
#  'christianism': 'christianity',
#  'jihads': 'jihad',
#  'fibronectin': 'proteins',
#  'vyasa': 'vishnu',
#  'caretakers': 'caretaker',
#  'elephanti': 'elephant',
#  'нарийвчлан': 'и',
#  'الاسود': 'و',
#  'http://www.sptimes.com/2006/08/16/neighborhoodtimes/a_senior_among_seniors.shtml': '0',
#  'mubashir': 'hussain',
#  'children.they': 'children',
#  'studying(not': 'studying',
#  'spaceship==': 'spaceship',
#  'redskin': 'redskins',
#  'discriminatorics': 'discrimination',
#  'sprachvergleichen': 'geschichte',
#  'vinkovci': 'zagreb',
#  '122.xx': '122',
#  'ארץ': 'ת',
#  'harutyunyan': 'yerevan',
#  'predominated': 'predominant',
#  'angiostrongylus': 'parasites',
#  'style=""background:#ffffff': 'background',
#  'antisubmarine': 'submarine',
#  'http://www.youtube.com/watch?v=mbdc2m7qxxk': 'youtube',
#  'http://www.vh1.com/interact/boards/main.jhtml/flavor_of_love_2/viewthread?tid=1143203&mid;=5738093&offset;=0&index;=0': 'www',
#  'گلستان': 'و',
#  'pc2-protection': 'protections',
#  'paragragh': 'paragraph',
#  'excretory': 'glands',
#  'habibullah': 'mohammad',
#  'microvesicle': 'membrane',
#  'synchronizing': 'synchronized',
#  'revertinng': 'reverted',
#  'reliable!~': 'reliable',
#  'तर': 'र',
#  'http://militera.lib.ru/memo/german/bidermann_gh/07.html': '0',
#  'ishida': 'takahashi',
#  'absorbent': 'coating',
#  'блокиран': 'и',
#  'epistemologist': 'philosopher',
#  'speciation': 'evolutionary',
#  'addapted': 'adapted',
#  'collaboration==': 'collaboration',
#  'standardbred': 'thoroughbred',
#  'fukuda': 'yamamoto',
#  'language2': 'language',
#  'gonadrotrophin': 'hormone',
#  'declared?the': 'declared',
#  'testbed': 'prototype',
#  'http://mongomutter.blogspot.com/2004/09/one-down.html': '0',
#  'lkndlkgndsknglkdsnviosdegl': '159',
#  'insurregents': 'insurrection',
#  'tobramycin': 'antibiotics',
#  'disscussions': 'discussions',
#  'brewed': 'beer',
#  'করার': 'এ',
#  'http://www.marca.com/multimedia/futbol/calculadora-liga/index.html': 'www',
#  'uncorrectly': 'correctly',
#  'gebrauch': 'und',
#  'restrictions)?anyways': 'restrictions',
#  'development:-': 'development',
#  'ioffensive': 'offensive',
#  'platonism': 'plato',
#  'minarchists': 'socialists',
#  'poon': 'cheung',
#  'armenianism': 'armenians',
#  'casablanca|date': 'casablanca',
#  'reliably': 'reliable',
#  'clackamas': 'oregon',
#  'warlord(ess': 'warlord',
#  'отель': 'и',
#  "theory)'d": 'theory',
#  'handbooks': 'handbook',
#  'józef': 'stanisław',
#  'додумався': 'и',
#  'аргументов': 'и',
#  'armeniac': 'armenia',
#  'brotherhoods': 'brotherhood',
#  'plasters': 'plaster',
#  'etymological': 'etymology',
#  'ако': 'и',
#  'section.—': 'sections',
#  'contextively': 'context',
#  'tourisms': 'tourism',
#  'hamad': 'abdullah',
#  'scoffs': 'confronts',
#  'kraków': 'wrocław',
#  'https://en.wikipedia.org/w/index.php?title=fokker&diff;=prev&oldid;=483249556': 'php',
#  'decides-': 'decides',
#  'শিশুদের': 'এ',
#  'aggravated!!!!is': 'aggravated',
#  '4|': 'ʂ',
#  'بايد': 'ـ',
#  'bakhtiari': 'kerman',
#  'http://en.wikipedia.org/w/index.php?title=wikipedia%3achanging_username&diff;=92790566&oldid;=92769124': 'php',
#  'http://www.time.com/time/magazine/article/0,9171,1844545,00.html': 'www',
#  'hjlfootball': 'football',
#  'शक्ति': 'र',
#  'pilings': 'piles',
#  'corticosteroids': 'medications',
#  'subroutines': 'implementations',
#  'buffalows': 'buffalo',
#  'known.http://supercentenarian-research-foundation.org/tablee.aspx': '0',
#  'августа': 'и',
#  'uracil': 'amino',
#  'limoges': 'toulouse',
#  'awear': 'apparel',
#  'http://www.dradio.de/dkultur/sendungen/interview/1261105/': 'www',
#  'prasanta': 'prasad',
#  'amphibolite': 'sedimentary',
#  'faislabad': 'lahore',
#  'slenderdan': 'slender',
#  'multilinear': 'orthogonal',
#  'suzerainty': 'vassal',
#  'interludes': 'interlude',
#  'vaccinationist': 'vaccine',
#  'accountant´s': 'accountants',
#  '–european': 'european',
#  'kidnaps': 'kidnap',
#  'interpretions': 'interpreting',
#  'consequents': 'consequence',
#  'http://www.teensadvisor.com/teen-dating/mutual-masturbation.html': '0',
#  '4-vector': 'vector',
#  'кончились': 'и',
#  'confirmation==': 'confirmation',
#  'òbjective': 'subjective',
#  'pdf-': 'pdf',
#  'http://de.youtube.com/watch?v=ijh2fqd1zpy': 'youtube',
#  'http://www.time.com/time/asia/magazine/article/0,13673,501021014-361785,00.html': 'www',
#  'http://www.iranchamber.com/personalities/farabi/farabi.php': '0',
#  'synthesizing': 'synthesis',
#  'christianity?==': 'christianity',
#  'krishan': 'kumar',
#  '想': '同',
#  'minting': 'coinage',
#  'fucke': 'fucked',
#  'позвоночника': 'и',
#  'https://en.wikipedia.org/w/index.php?title=orban&diff;=629385234&oldid;=621348395': 'php',
#  'cabinets==': 'cabinets',
#  'i-210': '210',
#  'umeå': 'gothenburg',
#  'romanovich': 'dmitry',
#  'http://propagandapress.org/2007/02/21/fuck-bubba-by-saab-lofton/': '0',
#  'millwall': 'tottenham',
#  'stupidly': 'stupid',
#  'golpur': 'patna',
#  'dispensationalism': 'doctrines',
#  'persönliche': 'eine',
#  'यही': 'এ',
#  'spacetime': 'relativity',
#  'особенно': 'и',
#  'krishnadevaraya)': 'krishna',
#  'confirms==': 'confirms',
#  'philosophía': 'philosophy',
#  'clumsily': 'awkwardly',
#  "o'connell": 'connell',
#  'genotype': 'genes',
#  'існування.': 'и',
#  'polański': 'stanisław',
#  'toomevara': 'kilkenny',
#  'attired': 'attire',
#  'ethnographer': 'anthropologist',
#  'penguinman': 'penguin',
#  'democrat/': 'democrats',
#  'piteşti': 'bucharest',
#  'fugues': 'symphonies',
#  'spectacles': 'spectacle',
#  'toshio': 'akira',
#  'compile': 'compiling',
#  'stuntman': 'stunt',
#  'النبيلة': 'ـ',
#  'الساعة': 'ـ',
#  ...}

# %%
import pickle

with open(bert_oov_map_path, 'wb') as of:
    pickle.dump(oov_map, of)

# %%
with open(bert_oov_map_path, 'b') as f:
    tmp = pickle.load(f)
# Out:
#   File "<ipython-input-232-d853e8f34684>", line 1
#     with open(bert_oov_map_path, 'b') as f
#                                           ^
# SyntaxError: invalid syntax
